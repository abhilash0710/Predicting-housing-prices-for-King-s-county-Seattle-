# %% [markdown]
# # INTRODUCTION TO THE DATASET

# %% [markdown]
# This dataset contains property listings for Kings County (includes Seattle) in Washington, USA.
# <br> We have picked this dataset from Kaggle.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Regression_dataset.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3        1.0         1180
# 1  6414100192  20141209T000000  538000.0         3        NaN         2570
# 2  5631500400  20150225T000000  180000.0         2        1.0          770
# 3  2487200875  20141209T000000  604000.0         4        3.0         1960
# 4  1954400510  20150218T000000  510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         0.0     0  ...    7.0        1180              0
# 1      7242     2.0         0.0     0  ...    7.0        2170            400
# 2     10000     1.0         0.0     0  ...    NaN         770              0
# 3      5000     1.0         0.0     0  ...    7.0        1050            910
# 4      8080     1.0         0.0     0  ...    8.0        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21135 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21601 non-null float64
# waterfront       21576 non-null float64
# view             21613 non-null int64
# condition        21588 non-null float64
# grade            21569 non-null float64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(8), int64(12), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## About the features

# %% [markdown]
# <br> 1. id: unique id for every listing
# <br> 2. date: date on which the listing was posted
# <br> 3. price: price for the property listing in dollars
# <br> 4. bedrooms: number of bedrooms in the property
# <br> 5. bathrooms: number of bathrooms in the property
# <br> 6. sqft_living: constructed area of the property in sqaure feet
# <br> 7. sqft_lot: lot size of the property in sqaure feet
# <br> 8. floors: number of floors
# <br> 9. waterfront: 0: property does not face a water body like a lake or pond, 1: property faces a water body like lake or pond
# <br> 10. view: number of times a property has been viewed
# <br> 11. condition: condition of the property on a scale of 1 to 5
# <br> 12. grade: score given to the property from King's county council on a scale of 1 to 13
# <br> 13. sqft_above: constructed area other than the basement in sqaure feet
# <br> 14. sqft_basement: constructed area of the basement in square feet
# <br> 15. yr_built: year in which the property was built
# <br> 16. yr_renovated: year in which the property was renovated
# <br> 17. zipcode: zipcode in which the property is located
# <br> 18. lat: latitude for the location of the property
# <br> 19. long: longitude for the location of the property
# <br> 20. sqft_living15: constructed area for the property in square feet (updated in 2015)
# <br> 21. sqft_lot15: lot size of the property in square feet (updated in 2015)

# %%
df.set_index('id', inplace=True)
# id is unique for every listing. Use it as an index to identify every listing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 20 columns):
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21135 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21601 non-null float64
# waterfront       21576 non-null float64
# view             21613 non-null int64
# condition        21588 non-null float64
# grade            21569 non-null float64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(8), int64(11), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## FEATURE: DATE

# %%
df.drop(columns = ['date'], inplace = True)
# dropping date because it is not useful for our analysis

# %% [markdown]
# ## FEATURE: PRICE

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.401822e+05
# std      3.673622e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ### 75% of the data has price between 75,000 and  645,000 dollars.

# %%
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(15, 10))

# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (15, 15)

# Size of matplotlib histogram bins
bin_size = 10

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['price'].hist()
plt.title('Price Histogram')
# Out:
# Text(0.5, 1.0, 'Price Histogram')

# %% [markdown]
# ## FEATURE: BEDROOMS

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['bedrooms'], ax = ax).set_title('Number of Bedrooms')
# Out:
# Text(0.5, 1.0, 'Number of Bedrooms')

# %% [markdown]
# ## FEATURE: BATHROOMS

# %%
df[df['bathrooms'].isnull()]
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 6414100192   538000.0         3        NaN         2570      7242     2.0
# 1321400060   257500.0         3        NaN         1715      6819     2.0
# 6054650070   400000.0         3        NaN         1370      9680     1.0
# 6300500875   385000.0         4        NaN         1620      4980     1.0
# 2524049179  2000000.0         3        NaN         3050     44867     1.0
# ...               ...       ...        ...          ...       ...     ...
# 191100405   1580000.0         4        NaN         3410     10125     2.0
# 249000205   1540000.0         5        NaN         4470      8088     2.0
# 844000965    224000.0         3        NaN         1500     11968     1.0
# 1523300141   402101.0         2        NaN         1020      1350     2.0
# 1523300157   325000.0         2        NaN         1020      1076     2.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 6414100192         0.0     0        3.0    7.0        2170            400
# 1321400060         0.0     0        3.0    7.0        1715              0
# 6054650070         0.0     0        4.0    7.0        1370              0
# 6300500875         0.0     0        4.0    7.0         860            760
# 2524049179         0.0     4        3.0    9.0        2330            720
# ...                ...   ...        ...    ...         ...            ...
# 191100405          0.0     0        3.0   10.0        3410              0
# 249000205          0.0     0        3.0   11.0        4470              0
# 844000965          0.0     0        3.0    6.0        1500              0
# 1523300141         0.0     0        3.0    7.0        1020              0
# 1523300157         0.0     0        3.0    7.0        1020              0
#
#             yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# id
# 6414100192      1951          1991    98125  47.7210 -122.319           1690
# 1321400060      1995             0    98003  47.3097 -122.327           2238
# 6054650070      1977             0    98074  47.6127 -122.045           1370
# 6300500875      1947             0    98133  47.7025 -122.341           1400
# 2524049179      1968             0    98040  47.5316 -122.233           4110
# ...              ...           ...      ...      ...      ...            ...
# 191100405       2007             0    98040  47.5653 -122.223           2290
# 249000205       2008             0    98004  47.6321 -122.200           2780
# 844000965       2014             0    98010  47.3095 -122.002           1320
# 1523300141      2009             0    98144  47.5944 -122.299           1020
# 1523300157      2008             0    98144  47.5941 -122.299           1020
#
#             sqft_lot15
# id
# 6414100192        7639
# 1321400060        6819
# 6054650070       10208
# 6300500875        4980
# 2524049179       20336
# ...                ...
# 191100405        10125
# 249000205         8964
# 844000965        11303
# 1523300141        2007
# 1523300157        1357
#
# [478 rows x 19 columns]

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    2869
# 2.00    1930
# 2.25    1909
# 1.50    1446
# 2.75    1109
# 3.00     753
# 3.50     731
# 3.25     535
# 3.75     142
# 4.00     136
# 4.50     100
# 4.25      77
# 0.75      63
# 5.00      21
# 4.75      20
# 5.25      12
# 5.50      10
# 0.00       9
# 1.25       8
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.50       2
# 6.75       2
# 6.25       1
# 7.75       1
# 7.50       1
# Name: bathrooms, dtype: int64

# %%
import seaborn as sns

fig_dims = (15, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['bathrooms'], ax = ax).set_title('Number of Bathrooms')
# Out:
# Text(0.5, 1.0, 'Number of Bathrooms')

# %% [markdown]
# ## FEATURE: SQFT_LIVING

# %%
df['sqft_living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_living'].hist()
plt.title('Sqaure Feet of Living Space Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet of Living Space Histogram')

# %% [markdown]
# ### 75% of the data has sqaure feet of living spave between 290 and 2550.

# %% [markdown]
# ## FEATURE: SQFT_LOT

# %%
df['sqft_lot'].describe()
# Out:
# count    2.161300e+04
# mean     1.510697e+04
# std      4.142051e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068800e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_lot'].hist()
plt.title('Sqaure Feet for Lot Size Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet for Lot Size Histogram')

# %% [markdown]
# ### 75% of the data has sqaure feet for the lot size between 520 and 10,688.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 19 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21135 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21601 non-null float64
# waterfront       21576 non-null float64
# view             21613 non-null int64
# condition        21588 non-null float64
# grade            21569 non-null float64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(8), int64(11)
# memory usage: 3.9 MB

# %% [markdown]
# ## FEATURE: FLOORS

# %%
df['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, nan, 3.5])

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['floors'], ax = ax).set_title('Number of Floors')
# Out:
# Text(0.5, 1.0, 'Number of Floors')

# %%
df['floors'].value_counts()
# Out:
# 1.0    10672
# 2.0     8238
# 1.5     1910
# 3.0      612
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ## FEATURE: WATERFRONT

# %%
df['waterfront'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['waterfront'], ax = ax).set_title('Waterfront (1:Yes, 0:No)')
# Out:
# Text(0.5, 1.0, 'Waterfront (1:Yes, 0:No)')

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    21413
# 1.0      163
# Name: waterfront, dtype: int64

# %% [markdown]
# ### 163 properties with a waterfront

# %% [markdown]
# ## FEATURE: VIEW

# %%
df['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['view'], ax = ax).set_title('Number of time a property has been viewed')
# Out:
# Text(0.5, 1.0, 'Number of time a property has been viewed')

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %% [markdown]
# ## FEATURE: CONDITION

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['condition'], ax = ax).set_title('Condition of a house (0: poor, 5: excellent)')
# Out:
# Text(0.5, 1.0, 'Condition of a house (0: poor, 5: excellent)')

# %%
df['condition'].value_counts()
# Out:
# 3.0    14017
# 4.0     5672
# 5.0     1697
# 2.0      172
# 1.0       30
# Name: condition, dtype: int64

# %% [markdown]
# ## FEATURE: GRADE

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(df['grade'], ax = ax).set_title('Overall Grade given by Kings county (0: Poor, 13: Excellent)')
# Out:
# Text(0.5, 1.0, 'Overall Grade given by Kings county (0: Poor, 13: Excellent)')

# %%
df['grade'].value_counts()
# Out:
# 7.0     8964
# 8.0     6055
# 9.0     2612
# 6.0     2029
# 10.0    1133
# 11.0     398
# 5.0      242
# 12.0      90
# 4.0       29
# 13.0      13
# 3.0        3
# 1.0        1
# Name: grade, dtype: int64

# %% [markdown]
# ## FEATURE: SQFT_ABOVE

# %%
df['sqft_above'].describe()
# Out:
# count    21613.000000
# mean      1788.390691
# std        828.090978
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max       9410.000000
# Name: sqft_above, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_above'].hist()
plt.title('Sqaure Feet for House without Basement Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet for House without Basement Histogram')

# %% [markdown]
# ### 75% of the dataset has square feet for house without basement between 290 and 2210.

# %% [markdown]
# ## FEATURE: SQFT_BASEMENT

# %%
df['sqft_basement'].describe()
# Out:
# count    21613.000000
# mean       291.509045
# std        442.575043
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        560.000000
# max       4820.000000
# Name: sqft_basement, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_basement'].hist()
plt.title('Sqaure Feet for Basement Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet for Basement Histogram')

# %% [markdown]
# ### 75% of the dataset has square feet for the basement between 0 and 560.

# %% [markdown]
# ## FEATURE: YR_BUILT

# %%
df['yr_built'].value_counts()
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %% [markdown]
# ### Listings from the year 1934 to 2014.

# %% [markdown]
# ## FEATURE: YR_RENOVATED

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# ### 20699 properties have not been renovated since they were built.

# %% [markdown]
# ## FEATURE: ZIP CODE

# %%
len(df['zipcode'].unique())
# Out:
# 70

# %% [markdown]
# ### 70 unique zip codes in the data set.

# %% [markdown]
# ## FEATURES: LAT, LONG

# %%
df.drop(columns = ['lat', 'long'], inplace = True)

# %% [markdown]
# ### Dropping Latitude, Longitude as they are not much useful for our analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 17 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21135 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21601 non-null float64
# waterfront       21576 non-null float64
# view             21613 non-null int64
# condition        21588 non-null float64
# grade            21569 non-null float64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(6), int64(11)
# memory usage: 3.6 MB

# %% [markdown]
# ## FEATURE: SQFT_LIVING15

# %%
df['sqft_living15'].describe()
# Out:
# count    21613.000000
# mean      1986.552492
# std        685.391304
# min        399.000000
# 25%       1490.000000
# 50%       1840.000000
# 75%       2360.000000
# max       6210.000000
# Name: sqft_living15, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_living15'].hist()
plt.title('Sqaure Feet for Living Space (2015) Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet for Living Space (2015) Histogram')

# %% [markdown]
# ### 75% of the dataset has sqaure feet for living space when updated in 2015 between 399 and 2360.

# %% [markdown]
# ## FEATURE: SQFT_LOT15

# %%
df['sqft_lot15'].describe()
# Out:
# count     21613.000000
# mean      12768.455652
# std       27304.179631
# min         651.000000
# 25%        5100.000000
# 50%        7620.000000
# 75%       10083.000000
# max      871200.000000
# Name: sqft_lot15, dtype: float64

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (2, 2)

plt.subplot2grid(fig_dims, (0, 0))
df['sqft_lot15'].hist()
plt.title('Sqaure Feet for Lot Size (2015) Histogram')
# Out:
# Text(0.5, 1.0, 'Sqaure Feet for Lot Size (2015) Histogram')

# %% [markdown]
# ### 75% of the dataset has square feet for lot size when updated in 2015 between 651 and 10,083.

# %% [markdown]
# # IMPUTING NULL VALUES AND FEATURE TRANSFORMATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 17 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21135 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21601 non-null float64
# waterfront       21576 non-null float64
# view             21613 non-null int64
# condition        21588 non-null float64
# grade            21569 non-null float64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(6), int64(11)
# memory usage: 3.6 MB

# %%
df.isna().sum()
# Out:
# price              0
# bedrooms           0
# bathrooms        478
# sqft_living        0
# sqft_lot           0
# floors            12
# waterfront        37
# view               0
# condition         25
# grade             44
# sqft_above         0
# sqft_basement      0
# yr_built           0
# yr_renovated       0
# zipcode            0
# sqft_living15      0
# sqft_lot15         0
# dtype: int64

# %% [markdown]
# ## IMPUTING VALUES FOR NUMBER OF FLOORS

# %%
train_grouped=df.groupby(['bedrooms', 'sqft_living15'])
df['floors'] = df['floors'].fillna(train_grouped['floors'].transform('median'))

# %%
df['floors'].value_counts()
# Out:
# 1.00    10679
# 2.00     8240
# 1.50     1912
# 3.00      612
# 2.50      161
# 3.50        8
# 1.75        1
# Name: floors, dtype: int64

# %% [markdown]
# ## IMPUTING VALUES FOR NUMBER OF BATHROOMS

# %%
train_grouped=df.groupby(['bedrooms', 'floors'])
df['bathrooms'] = df['bathrooms'].fillna(train_grouped['bathrooms'].transform('median'))

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5570
# 1.00    3867
# 1.75    3008
# 2.25    1972
# 2.00    1962
# 1.50    1447
# 2.75    1109
# 3.00     757
# 3.50     733
# 3.25     567
# 3.75     142
# 4.00     136
# 4.50     100
# 4.25      77
# 0.75      63
# 5.00      21
# 4.75      20
# 5.25      12
# 5.50      10
# 0.00       9
# 1.25       8
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.50       2
# 6.75       2
# 6.25       1
# 7.75       1
# 7.50       1
# Name: bathrooms, dtype: int64

# %% [markdown]
# ## IMPUTING VALUES FOR WATERFRONT

# %%
train_grouped=df.groupby(['zipcode', 'bedrooms', 'bathrooms'])
df['waterfront'] = df['waterfront'].fillna(train_grouped['waterfront'].transform('median'))

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    21449
# 1.0      163
# Name: waterfront, dtype: int64

# %% [markdown]
# ## ADDING A NEW FEATURE 'AGE OF THE PROPERTY'

# %% [markdown]
# ### Age of the property can be computed by subtracting the year in which the property was built from 2015. We subtract from 2015 because the listings are from that year.

# %%
df['property_age'] = ''

# %%
for i in range(0,len(df)):
    df.iloc[i,17] = 2015 - df.iloc[i,12]

# %% [markdown]
# ## ADDING A NEW FEATURE 'NUMBERS OF YEARS SINCE RENOVATION'

# %%
df['yr_last_renovated'] = ''

# %%
for i in range(0,len(df)):
    if df.iloc[i,13] == 0:
        df.iloc[i,18] = 0
    else:
        df.iloc[i,18] = 2015 - df.iloc[i,13]

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3        1.0         1180      5650     1.0
# 6414100192  538000.0         3        2.5         2570      7242     2.0
# 5631500400  180000.0         2        1.0          770     10000     1.0
# 2487200875  604000.0         4        3.0         1960      5000     1.0
# 1954400510  510000.0         3        2.0         1680      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520         0.0     0        3.0    7.0        1180              0
# 6414100192         0.0     0        3.0    7.0        2170            400
# 5631500400         0.0     0        3.0    NaN         770              0
# 2487200875         0.0     0        5.0    7.0        1050            910
# 1954400510         0.0     0        3.0    8.0        1680              0
#
#             yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15  \
# id
# 7129300520      1955             0    98178           1340        5650
# 6414100192      1951          1991    98125           1690        7639
# 5631500400      1933             0    98028           2720        8062
# 2487200875      1965             0    98136           1360        5000
# 1954400510      1987             0    98074           1800        7503
#
#             property_age  yr_last_renovated
# id
# 7129300520            60                  0
# 6414100192            64                 24
# 5631500400            82                  0
# 2487200875            50                  0
# 1954400510            28                  0

# %% [markdown]
# ### Now, we can drop yr_built and yr_renovated. Instead, use property_age and yr_last_renovated for our analysis.

# %%
df.drop(columns = ['yr_built', 'yr_renovated'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 7129300520 to 1523300157
# Data columns (total 17 columns):
# price                21613 non-null float64
# bedrooms             21613 non-null int64
# bathrooms            21613 non-null float64
# sqft_living          21613 non-null int64
# sqft_lot             21613 non-null int64
# floors               21613 non-null float64
# waterfront           21612 non-null float64
# view                 21613 non-null int64
# condition            21588 non-null float64
# grade                21569 non-null float64
# sqft_above           21613 non-null int64
# sqft_basement        21613 non-null int64
# zipcode              21613 non-null int64
# sqft_living15        21613 non-null int64
# sqft_lot15           21613 non-null int64
# property_age         21613 non-null int64
# yr_last_renovated    21613 non-null int64
# dtypes: float64(6), int64(11)
# memory usage: 3.6 MB

# %% [markdown]
# ## IMPUTING VALUES FOR CONDITION

# %%
train_grouped=df.groupby(['property_age', 'bedrooms', 'bathrooms'])
df['condition'] = df['condition'].fillna(train_grouped['condition'].transform('median'))

# %%
df['condition'].value_counts()
# Out:
# 3.0    14031
# 4.0     5680
# 5.0     1697
# 2.0      172
# 1.0       30
# 3.5        1
# Name: condition, dtype: int64

# %% [markdown]
# ## IMPUTING VALUES FOR GRADE

# %%
train_grouped=df.groupby(['property_age', 'bedrooms', 'bathrooms'])
df['grade'] = df['grade'].fillna(train_grouped['grade'].transform('median'))

# %%
df['grade'].value_counts()
# Out:
# 7.0     8986
# 8.0     6064
# 9.0     2616
# 6.0     2033
# 10.0    1134
# 11.0     398
# 5.0      242
# 12.0      90
# 4.0       29
# 13.0      13
# 3.0        3
# 6.5        2
# 1.0        1
# Name: grade, dtype: int64

# %%
df.drop(df[df['grade'].isnull()].index , inplace=True)
df.drop(df[df['condition'].isnull()].index , inplace=True)
df.drop(df[df['waterfront'].isnull()].index , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21608 entries, 7129300520 to 1523300157
# Data columns (total 17 columns):
# price                21608 non-null float64
# bedrooms             21608 non-null int64
# bathrooms            21608 non-null float64
# sqft_living          21608 non-null int64
# sqft_lot             21608 non-null int64
# floors               21608 non-null float64
# waterfront           21608 non-null float64
# view                 21608 non-null int64
# condition            21608 non-null float64
# grade                21608 non-null float64
# sqft_above           21608 non-null int64
# sqft_basement        21608 non-null int64
# zipcode              21608 non-null int64
# sqft_living15        21608 non-null int64
# sqft_lot15           21608 non-null int64
# property_age         21608 non-null int64
# yr_last_renovated    21608 non-null int64
# dtypes: float64(6), int64(11)
# memory usage: 3.0 MB

# %% [markdown]
# ## ONE HOT ENCODING FOR ZIP CODE

# %%
cols = pd.get_dummies(df['zipcode'], prefix= 'zip_code')
df[cols.columns] = cols
df.drop('zipcode', axis = 1, inplace = True)
# CREATED ONE HOT FOR ZIP CODE

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'sqft_living15', 'sqft_lot15', 'property_age',
#        'yr_last_renovated', 'zip_code_98001', 'zip_code_98002',
#        'zip_code_98003', 'zip_code_98004', 'zip_code_98005', 'zip_code_98006',
#        'zip_code_98007', 'zip_code_98008', 'zip_code_98010', 'zip_code_98011',
#        'zip_code_98014', 'zip_code_98019', 'zip_code_98022', 'zip_code_98023',
#        'zip_code_98024', 'zip_code_98027', 'zip_code_98028', 'zip_code_98029',
#        'zip_code_98030', 'zip_code_98031', 'zip_code_98032', 'zip_code_98033',
#        'zip_code_98034', 'zip_code_98038', 'zip_code_98039', 'zip_code_98040',
#        'zip_code_98042', 'zip_code_98045', 'zip_code_98052', 'zip_code_98053',
#        'zip_code_98055', 'zip_code_98056', 'zip_code_98058', 'zip_code_98059',
#        'zip_code_98065', 'zip_code_98070', 'zip_code_98072', 'zip_code_98074',
#        'zip_code_98075', 'zip_code_98077', 'zip_code_98092', 'zip_code_98102',
#        'zip_code_98103', 'zip_code_98105', 'zip_code_98106', 'zip_code_98107',
#        'zip_code_98108', 'zip_code_98109', 'zip_code_98112', 'zip_code_98115',
#        'zip_code_98116', 'zip_code_98117', 'zip_code_98118', 'zip_code_98119',
#        'zip_code_98122', 'zip_code_98125', 'zip_code_98126', 'zip_code_98133',
#        'zip_code_98136', 'zip_code_98144', 'zip_code_98146', 'zip_code_98148',
#        'zip_code_98155', 'zip_code_98166', 'zip_code_98168', 'zip_code_98177',
#        'zip_code_98178', 'zip_code_98188', 'zip_code_98198', 'zip_code_98199'],
#       dtype='object')

# %% [markdown]
# ## DROPPING SQFT_LIVING AND SQFT_LOT, INSTEAD USE THE UPDATED VALUES FOR THESE FEATURES : SQFT_LIVING15, SQFT_LOT15.
# The value for these features were updated in 2015.

# %%
df.drop(columns = ['sqft_living', 'sqft_lot'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21608 entries, 7129300520 to 1523300157
# Data columns (total 84 columns):
# price                21608 non-null float64
# bedrooms             21608 non-null int64
# bathrooms            21608 non-null float64
# floors               21608 non-null float64
# waterfront           21608 non-null float64
# view                 21608 non-null int64
# condition            21608 non-null float64
# grade                21608 non-null float64
# sqft_above           21608 non-null int64
# sqft_basement        21608 non-null int64
# sqft_living15        21608 non-null int64
# sqft_lot15           21608 non-null int64
# property_age         21608 non-null int64
# yr_last_renovated    21608 non-null int64
# zip_code_98001       21608 non-null uint8
# zip_code_98002       21608 non-null uint8
# zip_code_98003       21608 non-null uint8
# zip_code_98004       21608 non-null uint8
# zip_code_98005       21608 non-null uint8
# zip_code_98006       21608 non-null uint8
# zip_code_98007       21608 non-null uint8
# zip_code_98008       21608 non-null uint8
# zip_code_98010       21608 non-null uint8
# zip_code_98011       21608 non-null uint8
# zip_code_98014       21608 non-null uint8
# zip_code_98019       21608 non-null uint8
# zip_code_98022       21608 non-null uint8
# zip_code_98023       21608 non-null uint8
# zip_code_98024       21608 non-null uint8
# zip_code_98027       21608 non-null uint8
# zip_code_98028       21608 non-null uint8
# zip_code_98029       21608 non-null uint8
# zip_code_98030       21608 non-null uint8
# zip_code_98031       21608 non-null uint8
# zip_code_98032       21608 non-null uint8
# zip_code_98033       21608 non-null uint8
# zip_code_98034       21608 non-null uint8
# zip_code_98038       21608 non-null uint8
# zip_code_98039       21608 non-null uint8
# zip_code_98040       21608 non-null uint8
# zip_code_98042       21608 non-null uint8
# zip_code_98045       21608 non-null uint8
# zip_code_98052       21608 non-null uint8
# zip_code_98053       21608 non-null uint8
# zip_code_98055       21608 non-null uint8
# zip_code_98056       21608 non-null uint8
# zip_code_98058       21608 non-null uint8
# zip_code_98059       21608 non-null uint8
# zip_code_98065       21608 non-null uint8
# zip_code_98070       21608 non-null uint8
# zip_code_98072       21608 non-null uint8
# zip_code_98074       21608 non-null uint8
# zip_code_98075       21608 non-null uint8
# zip_code_98077       21608 non-null uint8
# zip_code_98092       21608 non-null uint8
# zip_code_98102       21608 non-null uint8
# zip_code_98103       21608 non-null uint8
# zip_code_98105       21608 non-null uint8
# zip_code_98106       21608 non-null uint8
# zip_code_98107       21608 non-null uint8
# zip_code_98108       21608 non-null uint8
# zip_code_98109       21608 non-null uint8
# zip_code_98112       21608 non-null uint8
# zip_code_98115       21608 non-null uint8
# zip_code_98116       21608 non-null uint8
# zip_code_98117       21608 non-null uint8
# zip_code_98118       21608 non-null uint8
# zip_code_98119       21608 non-null uint8
# zip_code_98122       21608 non-null uint8
# zip_code_98125       21608 non-null uint8
# zip_code_98126       21608 non-null uint8
# zip_code_98133       21608 non-null uint8
# zip_code_98136       21608 non-null uint8
# zip_code_98144       21608 non-null uint8
# zip_code_98146       21608 non-null uint8
# zip_code_98148       21608 non-null uint8
# zip_code_98155       21608 non-null uint8
# zip_code_98166       21608 non-null uint8
# zip_code_98168       21608 non-null uint8
# zip_code_98177       21608 non-null uint8
# zip_code_98178       21608 non-null uint8
# zip_code_98188       21608 non-null uint8
# zip_code_98198       21608 non-null uint8
# zip_code_98199       21608 non-null uint8
# dtypes: float64(6), int64(8), uint8(70)
# memory usage: 3.9 MB

# %% [markdown]
# # REGRESSION MODELS AND ANALYSIS

# %% [markdown]
# ### PRICE IS TARGET VARIABLE

# %%
X = df.drop(['price'], axis = 1)
y = df['price']

# %%
len(X.columns)
# Out:
# 83

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix

attributes = X.columns[:5]
scatter_matrix(X[attributes], figsize = (15,15), c = y, alpha = 0.8, marker = 'O')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C61A3108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C7EA2548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8034688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C81F87C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C822B908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8260A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8292B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C82C6D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C82CEB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C87D9548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C883BFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8875BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C88B07C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C88EA3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C891DF88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8959BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8993808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C89CC408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8A00F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8A3AD88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8A74E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8AABF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8AE9108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8B1D148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C8B55248>]],
#       dtype=object)

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix

attributes = X.columns[5:10]
scatter_matrix(X[attributes], figsize = (15,15), c = y, alpha = 0.8, marker = 'O')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CB327D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CB346E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9E83D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9EBE788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9EF71C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9F2EB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9F679C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9F9FB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9FAA708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167C9FE3888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA047E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA07FE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA0BBF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA0F8108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA12F248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA167348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA1A13C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA1D9508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA212608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA24A708>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA284848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA2BD948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CA2F49C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CB68EB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CB6C5C08>]],
#       dtype=object)

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix

attributes = X.columns[10:15]
scatter_matrix(X[attributes], figsize = (15,15), c = y, alpha = 0.8, marker = 'O')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCE3A3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCE832C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCE9B8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CC9D52C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCA0ACC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCA456C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCA7F088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCAB5BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCAC07C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCAF89C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCB5FF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCB96F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCBD30C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCC0C1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCC46308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCC7E408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCCB64C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCCF1608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCD29708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCD62808>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCD9B948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCDD3A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CCE0AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CD1D4C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000167CD20DD48>]],
#       dtype=object)

# %% [markdown]
# ## CHECKING FOR DATA LEAKAGE

# %%
columns = X
target = y

corr_list = []; 
for i in range(len(X.columns)):
    corr_list.append(np.corrcoef(columns.iloc[:,i],target)[0,1])

for i in range(len(corr_list)):
    if corr_list[i] >= 0.5:
        print(X.columns[i], ' ', round(corr_list[i], 4))
# Out:
# bathrooms   0.5187
# grade   0.6673
# sqft_above   0.6059
# sqft_living15   0.585

# %%
print(corr_list)
# Out:
# [0.3083594589361765, 0.5186585714110926, 0.25744987011382675, 0.2637619486255492, 0.396430361308104, 0.036859222941225185, 0.6673107783936755, 0.6059118235859404, 0.32306996824893724, 0.5849646206177209, 0.0824685929622751, -0.05367827356056376, 0.06958936539082772, -0.0922310812174531, -0.08034442892916133, -0.0768043772143547, 0.27146704506125086, 0.06517516833310152, 0.13388452751735627, 0.017039572717025223, 0.033127728761368665, -0.021634365531309648, -0.012929831681778492, -0.017333867453217258, -0.029588584153442683, -0.06397885793498992, -0.10614916110034336, 0.006776333201475536, 0.029236739222066443, -0.024363218033473747, 0.024275374752955877, -0.07277809981626318, -0.07398103547850786, -0.06003127207516818, 0.10271062400139602, -0.008047285007119157, -0.07886037213809603, 0.2127584331449846, 0.20517808014444688, -0.10042756413176263, -0.027864504495761996, 0.04733199246568763, 0.0520395602695864, -0.0720195666147662, -0.04495021513786569, -0.0745281322928754, -0.01884274197100275, -0.003976559041253352, -0.010624983812139988, 0.009239751754767421, 0.05505586447987311, 0.08877495691527543, 0.03741819334842722, -0.07184585665753927, 0.06882136997804096, 0.020736041942116715, 0.09113195768879115, -0.0754084195930616, 0.011868076849258126, -0.046827832072182045, 0.06596678590893489, 0.17015414760764264, 0.036231422596516044, 0.02667246861268013, 0.016223586677179897, -0.05177625304522625, 0.07819000206336492, 0.030022034693069712, -0.026761006537272453, -0.040571506133490524, -0.0638155111739213, 0.0035298978441152973, 0.018898975550206743, -0.057199916444069285, -0.03576322402202353, -0.046032933808231334, -0.022142662341346923, -0.09171637179495684, 0.040594894924441675, -0.06928155221638244, -0.054439141117664167, -0.0740613029285442, 0.0838213847926988]

# %% [markdown]
# ## SPLITTING AND SCALING THE DATASET

# %%
#using min max scaler for now
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)
print('Training data shape: '+str(X_train.shape))
print('Test data shape: '+ str(X_test.shape))
# Out:
# Training data shape: (16206, 83)
# Test data shape: (5402, 83)

# %% [markdown]
# We used Min Max Scaler becuase from the scatter plots shown above, it is observed that very few variables have a normal distribution.

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lreg = LinearRegression()

lreg.fit(X_train, y_train)
print('Train Score: ',lreg.score(X_train, y_train))
print('Test Score: ',lreg.score(X_test, y_test))

y_pred = lreg.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train Score:  0.8060534893262268
# Test Score:  0.8093805548111597
# MSE:  27248295899.047203

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X_train_rm = X_train[:,1].reshape(-1,1)
lreg.fit(X_train_rm, y_train)
y_predict = lreg.predict(X_train_rm)

plt.subplots(figsize = (20,5))
plt.plot(X_train_rm, y_predict, c = 'r')
plt.scatter(X_train_rm,y_train)
plt.xlabel('RM')
# Out:
# Text(0.5, 0, 'RM')

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# Degree:2

# %%
from  sklearn.preprocessing  import PolynomialFeatures

poly = PolynomialFeatures(degree = 2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)
lreg.fit(X_train_poly, y_train)

train_score = lreg.score(X_train_poly, y_train)
test_score = lreg.score(X_test_poly, y_test)

y_pred = lreg.predict(X_test_poly)
mse = mean_squared_error(y_test, y_pred)
    
print('Train Score: ', train_score)
print('Test Score: ', test_score)
print('MSE: ', mse)
# Out:
# Train Score:  0.9142562126015844
# Test Score:  -1.1574223313867433e+18
# MSE:  1.6544894532951572e+29

# %% [markdown]
# ## K-Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %matplotlib inline
train_score_array = []
test_score_array = []

for k in range(1,10):
    knn_reg = KNeighborsRegressor(k)
    knn_reg.fit(X_train, y_train)
    train_score_array.append(knn_reg.score(X_train, y_train))
    test_score_array.append(knn_reg.score(X_test, y_test))

x_axis = range(1,10)

plt.subplots(figsize = (20,5))
plt.plot(x_axis, train_score_array, c = 'g', label = 'Train Score')
plt.plot(x_axis, test_score_array, c = 'b', label = 'Test Score')
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

tuned_parameters=dict(n_neighbors=x_axis)

knn_reg = KNeighborsRegressor()
gri1 = GridSearchCV(knn_reg, tuned_parameters, cv = 3, return_train_score = True, iid = False)
gri_model1 = gri1.fit(X_train, y_train)

print(gri_model1.best_params_)
print('validation score: ', gri_model1.best_score_)

print('Train Score: ',gri_model1.score(X_train, y_train))
print('Test Score: ',gri_model1.score(X_test, y_test))

y_pred = gri_model1.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'n_neighbors': 3}
# validation score:  0.7470688771457796
# Train Score:  0.8895655611417164
# Test Score:  0.7889576318301038
# MSE:  30167671978.229298

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
# %matplotlib inline
import matplotlib.pyplot as plt

x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for alpha in x_range: 
    ridge = Ridge(alpha)
    ridge.fit(X_train,  y_train)
    train_score_list.append(ridge.score(X_train, y_train))
    test_score_list.append(ridge.score(X_test, y_test))
    

plt.subplots(figsize = (20,5))
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
plt.grid()

# %%
np.random.seed(0)
    
tuned_parameters = [{'alpha':x_range}]

ridge = Ridge(max_iter = 1000, tol = 0.1, random_state = 0)
gri2 = GridSearchCV(ridge, tuned_parameters, cv = 5, return_train_score = True, iid = False)
gri_model2 = gri2.fit(X_train, y_train)

print(gri2.best_params_)
print('validation score: ', gri2.best_score_)

print('Train Score: ',gri_model2.score(X_train, y_train))
print('Test Score: ',gri_model2.score(X_test, y_test))

y_pred = gri_model2.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'alpha': 0.1}
# validation score:  0.8022422771524044
# Train Score:  0.8060518957690112
# Test Score:  0.8093329406040315
# MSE:  27255102161.669266

# %%
# %matplotlib inline
import numpy as np

x_range1 = np.linspace(0.001, 1, 100).reshape(-1,1)
x_range2 = np.linspace(1, 10000, 10000).reshape(-1,1)

x_range = np.append(x_range1, x_range2)
coeff = []

for alpha in x_range: 
    ridge = Ridge(alpha)
    ridge.fit(X_train,y_train)
    coeff.append(ridge.coef_ )
    
coeff = np.array(coeff)

plt.subplots(figsize = (15,5))
for i in range(len(X.columns)):
    plt.plot(x_range, coeff[:,i])#, label = X.columns[i])

plt.axhline(y=0, xmin=0.001, xmax=9999, linewidth=1, c ='gray')
plt.xlabel(r'$\alpha$')
plt.xscale('log')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.5),
          ncol=3, fancybox=True, shadow=True)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# This figure is just to check at what value of alpha does the coefficients converge to zero.

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for alpha in x_range: 
    lasso = Lasso(alpha, max_iter=100, random_state=0)
    lasso.fit(X_train,y_train)
    train_score_list.append(lasso.score(X_train,y_train))
    test_score_list.append(lasso.score(X_test, y_test))
    
    
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
# Out:
# Text(0.5, 0, '$\\alpha$')

# %%
np.random.seed(0)

tuned_parameters = [{'alpha':x_range}]

lasso = Lasso(max_iter = 1000, tol=0.1, random_state=0)
gri3 = GridSearchCV(lasso, tuned_parameters, cv = 5, return_train_score = True, iid = False)
gri_model3 = gri3.fit(X_train,y_train)

print(gri_model3.best_params_)
print('validation score: ', gri_model3.best_score_)

print('Train Score: ',gri_model3.score(X_train, y_train))
print('Test Score: ',gri_model3.score(X_test, y_test))

y_pred = gri_model3.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'alpha': 1}
# validation score:  0.7981869642507479
# Train Score:  0.8002178535977403
# Test Score:  0.8036311094553662
# MSE:  28070156376.89543

# %%
lasso = Lasso(alpha = 1)
lasso.fit(X_train, y_train)
#dict(zip(X.columns, lasso.coef_))
plt.subplots(figsize = (20,5))
plt.style.use('ggplot')
plt.bar(range(len(X.columns)), lasso.coef_)
plt.box(False)
plt.xticks(range(len(X.columns)), X.columns, rotation = 45)
plt.grid()

# %% [markdown]
# sqft_above is the most important feature in this dataset based on the Lasso model with alpha = 1.

# %% [markdown]
# ## SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(random_state= 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)
sgd_reg.fit(X_train, y_train)
print('Train Score: ',sgd_reg.score(X_train, y_train))
print('Test Score: ',sgd_reg.score(X_test, y_test))

print("SGD regression coefficient: " + str(sgd_reg.coef_))
print("SGD regression intercept: " + str(sgd_reg.intercept_))
print("SGD regression iterations: " + str(sgd_reg.n_iter_))

y_pred = sgd_reg.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train Score:  0.7943173918495281
# Test Score:  0.7959419967553129
# SGD regression coefficient: [-6.63597242e+05  2.02707016e+05 -8.87675466e+04  5.88547849e+05
#   2.53800559e+05  8.55080971e+04  7.41995494e+05  1.70775363e+06
#   5.36113576e+05  1.10896871e+05  1.14726457e+05  6.88020166e+04
#  -3.82713028e+04 -2.22172190e+05 -1.81478257e+05 -2.15590298e+05
#   5.26867249e+05  1.38384691e+05  1.55768674e+05  3.50096035e+04
#   4.80777970e+04 -1.41339872e+05 -9.43097914e+04 -9.96789783e+04
#  -1.00718361e+05 -1.88729773e+05 -2.34378071e+05  3.26553009e+03
#  -1.67260743e+04 -8.80786185e+04 -1.78360381e+03 -2.09786031e+05
#  -1.81510758e+05 -2.04899683e+05  2.00210461e+05 -9.98303271e+03
#  -1.83778770e+05  1.05051324e+06  2.65520890e+05 -1.99548004e+05
#  -1.15489155e+05  2.09506630e+04  1.35168078e+03 -1.52560910e+05
#  -1.08571650e+05 -1.69765778e+05 -7.66812113e+04 -1.09200282e+05
#  -1.87428054e+05 -4.96997791e+04 -1.56810288e+04 -5.08765794e+04
#  -7.57386507e+04 -2.26959042e+05  2.40365327e+05  1.19744457e+05
#   2.30522187e+05 -1.02082352e+05  1.66943529e+05 -6.35996020e+04
#   3.11810583e+05  4.09701068e+05  1.18419447e+05  9.95168806e+04
#   1.02737848e+05 -1.97284617e+04  3.26674809e+05  1.04369210e+05
#  -1.07496419e+04 -1.33743856e+04 -1.23435888e+04  3.02842637e+04
#   8.30735910e+04 -9.12821788e+04 -1.33928781e+05 -5.79073558e+04
#  -9.40242140e+04 -1.13877211e+05  6.58485925e+04 -1.58413547e+05
#  -1.55741173e+05 -1.92561318e+05  2.46913753e+05]
# SGD regression intercept: [-296767.59821408]
# SGD regression iterations: 36
# MSE:  29169284631.332516

# %% [markdown]
# ## SVM Regressor

# %% [markdown]
# Linear SVR

# %%
from sklearn.svm import LinearSVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for e in [0.01, 0.1, 1, 10]:
        linear = LinearSVR(C = C, epsilon = e)
        linear.fit(X_train, y_train) 
        print('Train Score: ',linear.score(X_train,y_train),'C: ' ,C,'e: ' ,e)
        print('Test Score: ',linear.score(X_test, y_test),'C: ' ,C,'e: ' ,e)
# Out:
# Train Score:  -2.1926333202778827 C:  0.01 e:  0.01
# Test Score:  -2.0833949991511838 C:  0.01 e:  0.01
# Train Score:  -2.1926333202778827 C:  0.01 e:  0.1
# Test Score:  -2.0833949991511838 C:  0.01 e:  0.1
# Train Score:  -2.1926333202778827 C:  0.01 e:  1
# Test Score:  -2.0833949991511838 C:  0.01 e:  1
# Train Score:  -2.1926333202778827 C:  0.01 e:  10
# Test Score:  -2.0833949991511838 C:  0.01 e:  10
# Train Score:  -2.167391590011791 C:  0.1 e:  0.01
# Test Score:  -2.0597238907378026 C:  0.1 e:  0.01
# Train Score:  -2.167391590011791 C:  0.1 e:  0.1
# Test Score:  -2.0597238907378026 C:  0.1 e:  0.1
# Train Score:  -2.167391590011791 C:  0.1 e:  1
# Test Score:  -2.0597238907378026 C:  0.1 e:  1
# Train Score:  -2.167391590011791 C:  0.1 e:  10
# Test Score:  -2.0597238907378026 C:  0.1 e:  10
# Train Score:  -1.9225847664848543 C:  1 e:  0.01
# Test Score:  -1.8300415782183874 C:  1 e:  0.01
# Train Score:  -1.9225847664848539 C:  1 e:  0.1
# Test Score:  -1.830041578218387 C:  1 e:  0.1
# Train Score:  -1.9225847664848539 C:  1 e:  1
# Test Score:  -1.8300415782183874 C:  1 e:  1
# Train Score:  -1.9225847664848543 C:  1 e:  10
# Test Score:  -1.8300415782183874 C:  1 e:  10
# Train Score:  -0.4985149571248386 C:  10 e:  0.01
# Test Score:  -0.4869227756068044 C:  10 e:  0.01
# Train Score:  -0.498222611353657 C:  10 e:  0.1
# Test Score:  -0.4866438477112838 C:  10 e:  0.1
# Train Score:  -0.4982010795838203 C:  10 e:  1
# Test Score:  -0.48662423985633163 C:  10 e:  1
# Train Score:  -0.49839361718202624 C:  10 e:  10
# Test Score:  -0.48680719852555 C:  10 e:  10
# Train Score:  0.1611072510650804 C:  100 e:  0.01
# Test Score:  0.1479305622774214 C:  100 e:  0.01
# Train Score:  0.16085636337664544 C:  100 e:  0.1
# Test Score:  0.14768438907839687 C:  100 e:  0.1
# Train Score:  0.1614330955819776 C:  100 e:  1
# Test Score:  0.14825659918753475 C:  100 e:  1
# Train Score:  0.1604754435905621 C:  100 e:  10
# Test Score:  0.14730642313481135 C:  100 e:  10
# Train Score:  0.5752831294606251 C:  1000 e:  0.01
# Test Score:  0.557677036148575 C:  1000 e:  0.01
# Train Score:  0.5750773382557258 C:  1000 e:  0.1
# Test Score:  0.5574547678264246 C:  1000 e:  0.1
# Train Score:  0.5751550833330514 C:  1000 e:  1
# Test Score:  0.5575352433089307 C:  1000 e:  1
# Train Score:  0.5746803176617707 C:  1000 e:  10
# Test Score:  0.5570807862776721 C:  1000 e:  10
# Train Score:  0.7296704422108671 C:  10000 e:  0.01
# Test Score:  0.7220651222465895 C:  10000 e:  0.01
# Train Score:  0.7297251212237531 C:  10000 e:  0.1
# Test Score:  0.7220996789477028 C:  10000 e:  0.1
# Train Score:  0.7295944341556833 C:  10000 e:  1
# Test Score:  0.7219595476975914 C:  10000 e:  1
# Train Score:  0.7294745883459619 C:  10000 e:  10
# Test Score:  0.7218011254166901 C:  10000 e:  10

# %%
from sklearn.svm import LinearSVR
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.01, 0.1, 1, 10, 100, 1000, 10000],
             'epsilon': [0.01, 0.1, 1, 10]}

grid_search_linear = GridSearchCV(LinearSVR(), param_grid, cv=5, return_train_score = True)
svr_model_linear = grid_search_linear.fit(X_train, y_train) 

print(svr_model_linear.best_params_)
print('Validation score:', svr_model_linear.best_score_)

print('Train Score: ',svr_model_linear.score(X_train,y_train))
print('Test Score: ',svr_model_linear.score(X_test,y_test))

y_pred = svr_model_linear.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'epsilon': 10}
# Validation score: 0.7205539631211384
# Train Score:  0.7298528245559845
# Test Score:  0.7222774323620456
# MSE:  39699342810.201225

# %% [markdown]
# The value for C is quite big here through GridSearchCV but the values for train, validation and test scores are very close and it is interpreted that the model is able to generalize the complex structure of the data well.

# %% [markdown]
# Linear Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for e in [0.01, 0.1, 1, 10]:
        linear = SVR(kernel = 'linear', C = C, epsilon = e)
        linear.fit(X_train, y_train) 
        print('Train Score: ',linear.score(X_train,y_train),'C: ' ,C,'epsilon: ' ,e)
        print('Test Score: ',linear.score(X_test, y_test),'C: ' ,C,'epsilon: ' ,e)
# Out:
# Train Score:  -0.058841744623332026 C:  0.01 epsilon:  0.01
# Test Score:  -0.06454541200678832 C:  0.01 epsilon:  0.01
# Train Score:  -0.058841744623332026 C:  0.01 epsilon:  0.1
# Test Score:  -0.0645454120067881 C:  0.01 epsilon:  0.1
# Train Score:  -0.058841675146019456 C:  0.01 epsilon:  1
# Test Score:  -0.06454534120655309 C:  0.01 epsilon:  1
# Train Score:  -0.058851664088799716 C:  0.01 epsilon:  10
# Test Score:  -0.0645553912717558 C:  0.01 epsilon:  10
# Train Score:  -0.058672552752522256 C:  0.1 epsilon:  0.01
# Test Score:  -0.0643841723114904 C:  0.1 epsilon:  0.01
# Train Score:  -0.058672552752522256 C:  0.1 epsilon:  0.1
# Test Score:  -0.06438417231149063 C:  0.1 epsilon:  0.1
# Train Score:  -0.05867327117750798 C:  0.1 epsilon:  1
# Test Score:  -0.06438489503528255 C:  0.1 epsilon:  1
# Train Score:  -0.05867361825437167 C:  0.1 epsilon:  10
# Test Score:  -0.06438522795430246 C:  0.1 epsilon:  10
# Train Score:  -0.05691687299537618 C:  1 epsilon:  0.01
# Test Score:  -0.06270729398271335 C:  1 epsilon:  0.01
# Train Score:  -0.05691687299537618 C:  1 epsilon:  0.1
# Test Score:  -0.06270729398271335 C:  1 epsilon:  0.1
# Train Score:  -0.05691687299537618 C:  1 epsilon:  1
# Test Score:  -0.06270729398271335 C:  1 epsilon:  1
# Train Score:  -0.05691793525051114 C:  1 epsilon:  10
# Test Score:  -0.06270836779535616 C:  1 epsilon:  10
# Train Score:  -0.03832121927338128 C:  10 epsilon:  0.01
# Test Score:  -0.0448735519226755 C:  10 epsilon:  0.01
# Train Score:  -0.03832123771775198 C:  10 epsilon:  0.1
# Test Score:  -0.044873571396684575 C:  10 epsilon:  0.1
# Train Score:  -0.038321422161868846 C:  10 epsilon:  1
# Test Score:  -0.04487376613715388 C:  10 epsilon:  1
# Train Score:  -0.03831393971200403 C:  10 epsilon:  10
# Test Score:  -0.04486626058265086 C:  10 epsilon:  10
# Train Score:  0.1266995509138127 C:  100 epsilon:  0.01
# Test Score:  0.11409792759741912 C:  100 epsilon:  0.01
# Train Score:  0.12669955171404723 C:  100 epsilon:  0.1
# Test Score:  0.11409793132069335 C:  100 epsilon:  0.1
# Train Score:  0.12669955959794976 C:  100 epsilon:  1
# Test Score:  0.1140979684721648 C:  100 epsilon:  1
# Train Score:  0.12669885821526228 C:  100 epsilon:  10
# Test Score:  0.11409753525164001 C:  100 epsilon:  10
# Train Score:  0.5781156183028446 C:  1000 epsilon:  0.01
# Test Score:  0.5607577252492799 C:  1000 epsilon:  0.01
# Train Score:  0.5781155935415927 C:  1000 epsilon:  0.1
# Test Score:  0.5607576913846194 C:  1000 epsilon:  0.1
# Train Score:  0.5781153469212478 C:  1000 epsilon:  1
# Test Score:  0.56075735370623 C:  1000 epsilon:  1
# Train Score:  0.578110174255787 C:  1000 epsilon:  10
# Test Score:  0.5607510879952393 C:  1000 epsilon:  10
# Train Score:  0.7304696988680688 C:  10000 epsilon:  0.01
# Test Score:  0.7228313211268617 C:  10000 epsilon:  0.01
# Train Score:  0.7304697893785579 C:  10000 epsilon:  0.1
# Test Score:  0.7228314289267233 C:  10000 epsilon:  0.1
# Train Score:  0.7304706943571697 C:  10000 epsilon:  1
# Test Score:  0.7228324973608125 C:  10000 epsilon:  1
# Train Score:  0.7304751341451088 C:  10000 epsilon:  10
# Test Score:  0.722838208613544 C:  10000 epsilon:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

param_grid = {'C': [0.1, 1, 100, 1000, 10000],
              'epsilon': [0.01, 0.1, 1, 10]}

grid_search_linear = GridSearchCV(SVR(kernel = 'linear'), param_grid, cv=5, return_train_score = True)
svr_model_linear = grid_search_linear.fit(X_train, y_train) 

print(svr_model_linear.best_params_)
print('Validation score:', svr_model_linear.best_score_)

print('Train Score: ',svr_model_linear.score(X_train,y_train))
print('Test Score: ',svr_model_linear.score(X_test,y_test))

y_pred = svr_model_linear.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'epsilon': 1}
# Validation score: 0.721220625895948
# Train Score:  0.7304706943571697
# Test Score:  0.7228324973608125
# MSE:  39619998463.59157

# %% [markdown]
# The value for C is quite big here through GridSearchCV but the values for train, validation and test scores are very close and it is interpreted that the model is able to generalize the complex structure of the data well.

# %% [markdown]
# RBF Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for g in [0.01, 0.1, 1, 10]:
        rbf = SVR(kernel = 'rbf', C = C, gamma = g)
        rbf.fit(X_train, y_train) 
        print('Train Score: ',rbf.score(X_train,y_train),'C: ' ,C,'gamma: ' ,g)
        print('Test Score: ',rbf.score(X_test, y_test),'C: ' ,C,'gamma: ' ,g)
# Out:
# Train Score:  -0.058860057562585055 C:  0.01 gamma:  0.01
# Test Score:  -0.06456285850311949 C:  0.01 gamma:  0.01
# Train Score:  -0.058857429434937325 C:  0.01 gamma:  0.1
# Test Score:  -0.06456035305767349 C:  0.01 gamma:  0.1
# Train Score:  -0.05885604196977412 C:  0.01 gamma:  1
# Test Score:  -0.06455908072399641 C:  0.01 gamma:  1
# Train Score:  -0.05885972299779674 C:  0.01 gamma:  10
# Test Score:  -0.06456258089405731 C:  0.01 gamma:  10
# Train Score:  -0.058856707572268574 C:  0.1 gamma:  0.01
# Test Score:  -0.06455966333318397 C:  0.1 gamma:  0.01
# Train Score:  -0.05883135342105783 C:  0.1 gamma:  0.1
# Test Score:  -0.06453554345799772 C:  0.1 gamma:  0.1
# Train Score:  -0.058817219472000026 C:  0.1 gamma:  1
# Test Score:  -0.06452255784418348 C:  0.1 gamma:  1
# Train Score:  -0.05885391155641395 C:  0.1 gamma:  10
# Test Score:  -0.06455744101339 C:  0.1 gamma:  10
# Train Score:  -0.058824102927453215 C:  1 gamma:  0.01
# Test Score:  -0.06452861401207266 C:  1 gamma:  0.01
# Train Score:  -0.05856586357273619 C:  1 gamma:  0.1
# Test Score:  -0.0642826730367525 C:  1 gamma:  0.1
# Train Score:  -0.05840671845698897 C:  1 gamma:  1
# Test Score:  -0.06413484616403631 C:  1 gamma:  1
# Train Score:  -0.058791332772564875 C:  1 gamma:  10
# Test Score:  -0.064501536255553 C:  1 gamma:  10
# Train Score:  -0.05848870796189964 C:  10 gamma:  0.01
# Test Score:  -0.06420868075190245 C:  10 gamma:  0.01
# Train Score:  -0.05579893191217744 C:  10 gamma:  0.1
# Test Score:  -0.06164071449470554 C:  10 gamma:  0.1
# Train Score:  -0.05410379808281296 C:  10 gamma:  1
# Test Score:  -0.06005632940988148 C:  10 gamma:  1
# Train Score:  -0.05807458060034576 C:  10 gamma:  10
# Test Score:  -0.06385055976403486 C:  10 gamma:  10
# Train Score:  -0.05500520725474223 C:  100 gamma:  0.01
# Test Score:  -0.06087832305152485 C:  100 gamma:  0.01
# Train Score:  -0.026326461764727638 C:  100 gamma:  0.1
# Test Score:  -0.0333609583366099 C:  100 gamma:  0.1
# Train Score:  -0.00800866342334361 C:  100 gamma:  1
# Test Score:  -0.01603004354332671 C:  100 gamma:  1
# Train Score:  -0.049658401304008004 C:  100 gamma:  10
# Test Score:  -0.05606319372937896 C:  100 gamma:  10
# Train Score:  -0.018055287456109292 C:  1000 gamma:  0.01
# Test Score:  -0.025378902240884793 C:  1000 gamma:  0.01
# Train Score:  0.20722676680753438 C:  1000 gamma:  0.1
# Test Score:  0.1917784152598578 C:  1000 gamma:  0.1
# Train Score:  0.28087096954660473 C:  1000 gamma:  1
# Test Score:  0.2617600432647653 C:  1000 gamma:  1
# Train Score:  0.027492167309609794 C:  1000 gamma:  10
# Test Score:  0.01597658494313059 C:  1000 gamma:  10
# Train Score:  0.253266142655431 C:  10000 gamma:  0.01
# Test Score:  0.23674186242697123 C:  10000 gamma:  0.01
# Train Score:  0.6192422886360438 C:  10000 gamma:  0.1
# Test Score:  0.6035700481078412 C:  10000 gamma:  0.1
# Train Score:  0.6042293447994029 C:  10000 gamma:  1
# Test Score:  0.5848772363248858 C:  10000 gamma:  1
# Train Score:  0.26404985985837415 C:  10000 gamma:  10
# Test Score:  0.23200307927676778 C:  10000 gamma:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'C': [0.1, 1, 100, 1000, 10000],
              'gamma': [0.01, 0.1, 1, 10]}

grid_search_rbf = GridSearchCV(SVR(kernel = 'rbf'), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_rbf = grid_search_rbf.fit(X_train, y_train) 

print(svr_model_rbf.best_params_)
print('Validation score:', svr_model_rbf.best_score_)

print('Train Score: ',svr_model_rbf.score(X_train,y_train))
print('Test Score: ',svr_model_rbf.score(X_test,y_test))

y_pred = svr_model_rbf.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'gamma': 0.1}
# Validation score: 0.5975357687075278
# Train Score:  0.6192422886360438
# Test Score:  0.6035700481078412
# MSE:  56668093969.64391

# %% [markdown]
# The value for C is quite big here through GridSearchCV but the values for train, validation and test scores are very close and it is interpreted that the model is able to generalize the complex structure of the data well.

# %% [markdown]
# Poly Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for coef in [0.01, 0.1, 1, 10]:
        poly = SVR(kernel = 'poly', degree = 3, C = C, coef0 = coef)
        poly.fit(X_train, y_train)
        print('Train Score: ',poly.score(X_train,y_train),'C: ' ,C,'coef0: ' ,coef)
        print('Test Score: ',poly.score(X_test, y_test),'C: ' ,C,'coef0: ' ,coef)
# Out:
# Train Score:  -0.058860483302784816 C:  0.01 coef0:  0.01
# Test Score:  -0.0645632673791603 C:  0.01 coef0:  0.01
# Train Score:  -0.0588604724393591 C:  0.01 coef0:  0.1
# Test Score:  -0.06456325693199982 C:  0.01 coef0:  0.1
# Train Score:  -0.058859668645011576 C:  0.01 coef0:  1
# Test Score:  -0.06456248516857932 C:  0.01 coef0:  1
# Train Score:  -0.05879235044505071 C:  0.01 coef0:  10
# Test Score:  -0.0644983387767355 C:  0.01 coef0:  10
# Train Score:  -0.0588604763492695 C:  0.1 coef0:  0.01
# Test Score:  -0.06456326066470086 C:  0.1 coef0:  0.01
# Train Score:  -0.058860367715022566 C:  0.1 coef0:  0.1
# Test Score:  -0.06456315619310238 C:  0.1 coef0:  0.1
# Train Score:  -0.058853284884907264 C:  0.1 coef0:  1
# Test Score:  -0.06455639943678926 C:  0.1 coef0:  1
# Train Score:  -0.05816797829911625 C:  0.1 coef0:  10
# Test Score:  -0.06390265777647652 C:  0.1 coef0:  10
# Train Score:  -0.05886040681415361 C:  1 coef0:  0.01
# Test Score:  -0.06456319352014295 C:  1 coef0:  0.01
# Train Score:  -0.05885935414610022 C:  1 coef0:  0.1
# Test Score:  -0.06456218266338332 C:  1 coef0:  0.1
# Train Score:  -0.058789748679250575 C:  1 coef0:  1
# Test Score:  -0.06449584804146569 C:  1 coef0:  1
# Train Score:  -0.051536781315135505 C:  1 coef0:  10
# Test Score:  -0.057553585303113726 C:  1 coef0:  10
# Train Score:  -0.05885971146314839 C:  10 coef0:  0.01
# Test Score:  -0.0645625220747057 C:  10 coef0:  0.01
# Train Score:  -0.05885008765680033 C:  10 coef0:  0.1
# Test Score:  -0.0645533218739045 C:  10 coef0:  0.1
# Train Score:  -0.05813893097183431 C:  10 coef0:  1
# Test Score:  -0.0638747010558085 C:  10 coef0:  1
# Train Score:  0.015608215510193424 C:  10 coef0:  10
# Test Score:  0.007027305981996745 C:  10 coef0:  10
# Train Score:  -0.05885306260785694 C:  100 coef0:  0.01
# Test Score:  -0.06455611377752657 C:  100 coef0:  0.01
# Train Score:  -0.058757819453904236 C:  100 coef0:  0.1
# Test Score:  -0.06446511232244045 C:  100 coef0:  0.1
# Train Score:  -0.051242434251250295 C:  100 coef0:  1
# Test Score:  -0.057269943497422655 C:  100 coef0:  1
# Train Score:  0.40052328693103967 C:  100 coef0:  10
# Test Score:  0.3812604518469042 C:  100 coef0:  10
# Train Score:  -0.05878764802572678 C:  1000 coef0:  0.01
# Test Score:  -0.0644931132389508 C:  1000 coef0:  0.01
# Train Score:  -0.0578200836189553 C:  1000 coef0:  0.1
# Test Score:  -0.06356780990485666 C:  1000 coef0:  0.1
# Train Score:  0.01844313407259679 C:  1000 coef0:  1
# Test Score:  0.009772639411822714 C:  1000 coef0:  1
# Train Score:  0.6851370563131076 C:  1000 coef0:  10
# Test Score:  0.6735454685448281 C:  1000 coef0:  10
# Train Score:  -0.058127393106407244 C:  10000 coef0:  0.01
# Test Score:  -0.06385690524332732 C:  10000 coef0:  0.01
# Train Score:  -0.04804753922497951 C:  10000 coef0:  0.1
# Test Score:  -0.05419291795007419 C:  10000 coef0:  0.1
# Train Score:  0.41064186032798444 C:  10000 coef0:  1
# Test Score:  0.3913899713502945 C:  10000 coef0:  1
# Train Score:  0.7593349014269299 C:  10000 coef0:  10
# Test Score:  0.7552182592565814 C:  10000 coef0:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'C': [0.1, 1, 10, 100, 1000, 10000],
              'coef0': [0.01, 0.1, 1, 10]}

grid_search_poly = GridSearchCV(SVR(kernel = 'poly'), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_poly = grid_search_poly.fit(X_train, y_train) 

print(svr_model_poly.best_params_)
print('Validation score:', svr_model_poly.best_score_)

print('Train Score: ',svr_model_poly.score(X_train,y_train))
print('Test Score: ',svr_model_poly.score(X_test,y_test))

y_pred = svr_model_poly.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'coef0': 10}
# Validation score: 0.7549443634453178
# Train Score:  0.7593349014269299
# Test Score:  0.7552182592565814
# MSE:  34990581867.725494

# %% [markdown]
# The value for C is quite big here through GridSearchCV but the values for train, validation and test scores are very close and it is interpreted that the model is able to generalize the complex structure of the data well.

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

for leaf in [2, 5, 7, 10, 15, 20]:
    dtr = DecisionTreeRegressor(min_samples_leaf = leaf)
    dtr.fit(X_train, y_train)
    print('Train Score: ',dtr.score(X_train,y_train),'min_samples_leaf: ' ,leaf)
    print('Test Score: ',dtr.score(X_test, y_test),'min_samples_leaf: ' ,leaf)
# Out:
# Train Score:  0.9717889424523308 min_samples_leaf:  2
# Test Score:  0.6581794040004993 min_samples_leaf:  2
# Train Score:  0.8891731888650789 min_samples_leaf:  5
# Test Score:  0.6739666513490716 min_samples_leaf:  5
# Train Score:  0.8520510595015419 min_samples_leaf:  7
# Test Score:  0.7219658538057803 min_samples_leaf:  7
# Train Score:  0.8243602213067842 min_samples_leaf:  10
# Test Score:  0.7004812966528191 min_samples_leaf:  10
# Train Score:  0.7792949543439533 min_samples_leaf:  15
# Test Score:  0.6930623920550905 min_samples_leaf:  15
# Train Score:  0.7571364547437054 min_samples_leaf:  20
# Test Score:  0.6889514577171962 min_samples_leaf:  20

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {'min_samples_leaf': range(3,20)}

dtr = GridSearchCV(DecisionTreeRegressor(), param_grid, cv = 5, return_train_score = True, n_jobs = -1)
decision_tree = dtr.fit(X_train, y_train)

## tree_model = clf.best_estimator_
print(decision_tree.best_params_)
print('Validation score:', decision_tree.best_score_)

print('Train Score: ',decision_tree.score(X_train,y_train))
print('Test Score: ',decision_tree.score(X_test,y_test))

y_pred = decision_tree.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'min_samples_leaf': 9}
# Validation score: 0.6800405443270736
# Train Score:  0.8315005319288606
# Test Score:  0.7006875337562508
# MSE:  42785533440.21972

# %% [markdown]
# # CONCLUSION
# After running all the models and comparing the performance on training and testing data sets, it is observed that Linear Regression and Ridge Regression (alpha = 0.1) have the highest training and testing scores among all the models.
# <br> The top 4 models are mentioned here in decreasing order of training and testing scores: Linear Regression > Ridge Regression > Lasso Regression > SGD Regressor
#
#
# ### Best Parameters for every model
# | Model | Parameters |
# | --- | --- |
# | Polynomial Regression | Degree = 2 |
# | KNN Regressor | k = 3 |
# | Ridge Regression | alpha = 0.1 |
# | Lasso Regression | alpha = 1 |
# | SGD Regressor | number of iterations = 36 |
# | Linear SVR | C = 10000, epsilon = 0.01 |
# | SVR Linear Kernel | C = 10000, epsilon = 1 |
# | SVR RBF Kernel | C = 10000, gamma = 0.1 |
# | SVR Poly Kernel | C = 10000, coef0 = 10 |
# | Decision Tree Regressor | min_samples_leaf = 9 |
#
#
# ### Performance on Dataset
# | Model | Linear Regression | Polynomial Regression | KNN Regressor | Ridge Regression | Lasso Regression | SGD Regressor | Linear SVR | SVM Linear | SVM RBF | SVM Poly | Decision Tree Regressor |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Params | default | degree = 2 | k = 3 | alpha = 0.1 | alpha = 1 | number of iterations = 36 | C = 10000, epsilon = 0.01 | C = 10000, epsilon = 0.01 | C=10000, gamma=0.1 | C = 10, coef0 = 10 | min_samples_leaf = 9 |
# | Training Score | 0.8060 | 0.9145 | 0.8896| 0.8061 | 0.8002 | 0.7943 | 0.7301 | 0.7305 | 0.5975 | 0.7593 | 0.8315 |
# | Validation Score | - | - | 0.7471| 0.8022 | 0.7982 | - | 0.7205 | 0.7212 | 0.5975 | 0.7594 | 0.6801 |
# |Testing score | 0.8094 | -8.7553e+16 | 0.7890 | 0.8093 | 0.8036 | 0.7959 | 0.7225 | 0.7228 | 0.6036 | 0.7552 | 0.7007 |
# | MSE | 27248083255.0241 | 1.2515e+28 | 30167671978.2293 | 27255102161.6693 | 28070156376.8954 | 29169284631.3325 | 39673213678.8975 | 39619998463.59157 | 56668093969.6439 | 34990581867.725494 | 42785533440.2197 |

# %% [markdown]
# ## Linear Regression with default parameters

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lreg = LinearRegression()

lreg.fit(X_train, y_train)
print('Train Score: ',lreg.score(X_train, y_train))
print('Test Score: ',lreg.score(X_test, y_test))

y_pred = lreg.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train Score:  0.8060534893262268
# Test Score:  0.8093805548111597
# MSE:  27248295899.047203

# %% [markdown]
# ## Ridge Regression with alpha = 0.1

# %%
from  sklearn.linear_model import Ridge

ridge = Ridge(alpha = 0.1)
ridge.fit(X_train,y_train)
print('Train score: ',ridge.score(X_train,y_train))
print('Test score: ', ridge.score(X_test, y_test))
y_pred = ridge.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train score:  0.8060518957690112
# Test score:  0.8093329406040315
# MSE:  27255102161.669266

# %% [markdown]
# # PROJECT 2

# %% [markdown]
# ## Bagging for SGD Regressor

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import SGDRegressor

n_estimators = [20,50,150,250,500]
max_features = [1,5,10,15,20]
param_list = []
train_score_list = []
test_score_list = []

for estimator in n_estimators:
    for features in max_features:
        sgd_reg = SGDRegressor(random_state = 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)
        bag_reg = BaggingRegressor(sgd_reg, max_samples = 0.5, max_features = features, n_estimators = estimator,
                               bootstrap = True, random_state = 0, oob_score = True)
        
        bag_reg.fit(X_train, y_train)
        train_score_list.append(bag_reg.score(X_train, y_train))
        test_score_list.append(bag_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "max_features: " + str(features))
        
#f, axes = plt.subplots(1,2)    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
#plt.ylabel("Test Score")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,150,250,500],
              "max_features":[1,5,10,15,20],
              "max_samples": [0.1,0.3,0.5]}

sgd_reg = SGDRegressor(random_state = 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)

sgd_bag_grid = GridSearchCV(BaggingRegressor(sgd_reg, bootstrap = True, oob_score = True, random_state = 0), param_grid, n_jobs = -1)
sgd_bag_grid_model = sgd_bag_grid.fit(X_train, y_train)

print(sgd_bag_grid_model.best_params_)
print('Validation score: ',sgd_bag_grid_model.best_score_)

print('Train Score: ',sgd_bag_grid_model.score(X_train, y_train))
print('Test Score: ',sgd_bag_grid_model.score(X_test, y_test))

y_pred = sgd_bag_grid_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'max_features': 20, 'max_samples': 0.3, 'n_estimators': 20}
# Validation score:  0.5677115662754662
# Train Score:  0.5589871547840561
# Test Score:  0.5509060711366776
# MSE:  64196201221.81469

# %% [markdown]
# ## Pasting for SGD Regressor

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import SGDRegressor

n_estimators = [20,50,150,250,500]
max_features = [1,5,10,15,20]
param_list = []
train_score_list = []
test_score_list = []

for estimator in n_estimators:
    for features in max_features:
        sgd_reg = SGDRegressor(random_state = 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)
        bag_reg = BaggingRegressor(sgd_reg, max_samples = 0.5, max_features = features, n_estimators = estimator,
                               bootstrap = False, random_state = 0)
        
        bag_reg.fit(X_train, y_train)
        train_score_list.append(bag_reg.score(X_train, y_train))
        test_score_list.append(bag_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "max_features: " + str(features))
        
#f, axes = plt.subplots(1,2)    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
#plt.ylabel("Test Score")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,150,250,500],
              "max_features":[1,5,10,15,20],
              "max_samples": [0.1,0.3,0.5]}

sgd_reg = SGDRegressor(random_state = 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)
#sgd_reg = SGDRegressor(random_state = 0)

sgd_bag_grid = GridSearchCV(BaggingRegressor(sgd_reg, bootstrap = False, random_state = 0), param_grid,
                           cv = 5, return_train_score = True, n_jobs = -1)
sgd_bag_grid_model = sgd_bag_grid.fit(X_train, y_train)

print(sgd_bag_grid_model.best_params_)
print('Validation score: ',sgd_bag_grid_model.best_score_)

print('Train Score: ',sgd_bag_grid_model.score(X_train, y_train))
print('Test Score: ',sgd_bag_grid_model.score(X_test, y_test))

y_pred = sgd_bag_grid_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'max_features': 20, 'max_samples': 0.5, 'n_estimators': 20}
# Validation score:  0.5693555465285673
# Train Score:  0.5662121617324214
# Test Score:  0.5587716348344909
# MSE:  63071849995.010414

# %% [markdown]
# For SGD Regressor, the best parameters obtained through Porject 1 are used for both Bagging and Pasting with and without Grid Search.

# %% [markdown]
# ## Bagging for Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor

n_estimators = [20,50,150,250,500]
max_features = [1,5,10,15,20]
param_list = []
train_score_list = []
test_score_list = []

dtr = DecisionTreeRegressor(min_samples_leaf = 9)

for estimator in n_estimators:
    for features in max_features:
        bag_reg = BaggingRegressor(dtr, max_samples = 0.5, max_features = features, n_estimators = estimator,
                               bootstrap = True, random_state = 0, oob_score = True)
        
        bag_reg.fit(X_train, y_train)
        train_score_list.append(bag_reg.score(X_train, y_train))
        test_score_list.append(bag_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "max_features: " + str(features))
        
    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,150,250,500],
              "max_features":[1,5,10,15,20],
              "max_samples": [0.1,0.3,0.5]}

dtr = DecisionTreeRegressor(min_samples_leaf = 9)

dtr_bag_grid = GridSearchCV(BaggingRegressor(dtr, bootstrap = True, oob_score = True, random_state = 0), param_grid,
                           cv = 5, return_train_score = True, n_jobs = -1)
dtr_bag_grid_model = dtr_bag_grid.fit(X_train, y_train)

print(dtr_bag_grid_model.best_params_)
print('Validation score: ',dtr_bag_grid_model.best_score_)

print('Train Score: ',dtr_bag_grid_model.score(X_train, y_train))
print('Test Score: ',dtr_bag_grid_model.score(X_test, y_test))

y_pred = dtr_bag_grid_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'max_features': 20, 'max_samples': 0.5, 'n_estimators': 250}
# Validation score:  0.6113193325992352
# Train Score:  0.658800640471781
# Test Score:  0.6278667258154307
# MSE:  53194979970.78448

# %% [markdown]
# ## Pasting for Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor

n_estimators = [20,50,150,250,500]
max_features = [1,5,10,15,20]
param_list = []
train_score_list = []
test_score_list = []

dtr = DecisionTreeRegressor(min_samples_leaf = 9)

for estimator in n_estimators:
    for features in max_features:
        bag_reg = BaggingRegressor(dtr, max_samples = 0.5, max_features = features, n_estimators = estimator,
                               bootstrap = False, random_state = 0)
        
        bag_reg.fit(X_train, y_train)
        train_score_list.append(bag_reg.score(X_train, y_train))
        test_score_list.append(bag_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "max_features: " + str(features))
        
    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,150,250,500],
              "max_features":[1,5,10,15,20],
              "max_samples": [0.1,0.3,0.5]}

dtr = DecisionTreeRegressor(min_samples_leaf = 9)

dtr_bag_grid = GridSearchCV(BaggingRegressor(dtr, bootstrap = False, random_state = 0), param_grid,
                           cv = 5, return_train_score = True, n_jobs = -1)
dtr_bag_grid_model = dtr_bag_grid.fit(X_train, y_train)

print(dtr_bag_grid_model.best_params_)
print('Validation score: ',dtr_bag_grid_model.best_score_)

print('Train Score: ',dtr_bag_grid_model.score(X_train, y_train))
print('Test Score: ',dtr_bag_grid_model.score(X_test, y_test))

y_pred = dtr_bag_grid_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'max_features': 20, 'max_samples': 0.5, 'n_estimators': 250}
# Validation score:  0.618597061404007
# Train Score:  0.6734508635945906
# Test Score:  0.6354711358183972
# MSE:  52107959631.94532

# %% [markdown]
# For Decision Tree Regressor, the best parameters obtained through Porject 1 are used for both Bagging and Pasting with and without Grid Search.

# %% [markdown]
# ## Adaboosting for Linear Regression

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
# %matplotlib inline

n_estimators = [20,50,100,250,500]
learning_rate = [0.05,0.1,0.3,0.5,0.7,1]
param_list = []
train_score_list = []
test_score_list = []

lreg = LinearRegression()

for estimator in n_estimators:
    for rate in learning_rate:
        adb_reg = AdaBoostRegressor(lreg, random_state=0, n_estimators = estimator, learning_rate = rate, loss = "square")
        
        adb_reg.fit(X_train, y_train)
        train_score_list.append(adb_reg.score(X_train, y_train))
        test_score_list.append(adb_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "learning_rate: " + str(rate))
    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,100,250,500],
              "learning_rate":[0.05,0.1,0.3,0.5,0.7,1],
              "loss" : ["exponential", "linear", "square"]}
lreg = LinearRegression()

grid_adb_lreg = GridSearchCV(AdaBoostRegressor(lreg, random_state = 0), param_grid, n_jobs = -1)
grid_adb_lreg_model = grid_adb_lreg.fit(X_train, y_train)

print(grid_adb_lreg_model.best_params_)
print('Validation score: ',grid_adb_lreg_model.best_score_)

print('Train Score: ',grid_adb_lreg_model.score(X_train, y_train))
print('Test Score: ',grid_adb_lreg_model.score(X_test, y_test))

y_pred = grid_adb_lreg_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'learning_rate': 0.05, 'loss': 'exponential', 'n_estimators': 20}
# Validation score:  0.794050779239547
# Train Score:  0.8029734946676835
# Test Score:  0.8083587082006737
# MSE:  27394364831.198273

# %% [markdown]
# Default parameters for linear regression are used in adaboosting.

# %% [markdown]
# ## Adaboosting for Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.ensemble import AdaBoostRegressor
# %matplotlib inline

n_estimators = [20,50,100,250,500]
learning_rate = [0.05,0.1,0.3,0.5,0.7,1]
param_list = []
train_score_list = []
test_score_list = []

lasso = Lasso(alpha = 1, max_iter = 1000, tol = 0.1, random_state = 0)

for estimator in n_estimators:
    for rate in learning_rate:
        adb_reg = AdaBoostRegressor(lasso, random_state=0, n_estimators = estimator, learning_rate = rate, loss = "square")
        
        adb_reg.fit(X_train, y_train)
        train_score_list.append(adb_reg.score(X_train, y_train))
        test_score_list.append(adb_reg.score(X_test, y_test))
        param_list.append("n_estimators: " + str(estimator) + ' ' + "learning_rate: " + str(rate))
    
plt.plot(param_list, train_score_list, c = 'g', label = 'Train Score')
plt.plot(param_list, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel("Number of estimators")
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [20,50,100,250,500],
              "learning_rate":[0.05,0.1,0.3,0.5,0.7,1],
              "loss" : ["exponential", "linear", "square"]}
lasso = Lasso(alpha = 1, max_iter = 1000, tol = 0.1, random_state = 0)

grid_adb_lasso = GridSearchCV(AdaBoostRegressor(lasso, random_state = 0), param_grid, n_jobs = -1)
grid_adb_lasso_model = grid_adb_lasso.fit(X_train, y_train)

print(grid_adb_lasso_model.best_params_)
print('Validation score: ',grid_adb_lasso_model.best_score_)

print('Train Score: ',grid_adb_lasso_model.score(X_train, y_train))
print('Test Score: ',grid_adb_lasso_model.score(X_test, y_test))

y_pred = grid_adb_lasso_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'learning_rate': 0.05, 'loss': 'exponential', 'n_estimators': 20}
# Validation score:  0.7943769838727383
# Train Score:  0.8015160513474398
# Test Score:  0.8072484926447483
# MSE:  27553065754.651333

# %% [markdown]
# For Lasso Regression, the best parameters obtained through Porject 1 are used for adaboosting with and without Grid Search.

# %% [markdown]
# ## Gradient Boosting

# %%
from  sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {"n_estimators": [50,100,150,250,500],
              "learning_rate":[0.05,0.1,0.3,0.5,0.7,1],
              "max_depth": [3,5,7],
              "max_features":['auto', 'sqrt', 'log2']}

gbrt_reg = GridSearchCV(GradientBoostingRegressor(random_state = 0), param_grid)
gbrt_reg_model = gbrt_reg.fit(X_train,y_train)

print(gbrt_reg_model.best_params_)
print('Validation score: ',gbrt_reg_model.best_score_)

print('Train Score: ',gbrt_reg_model.score(X_train, y_train))
print('Test Score: ',gbrt_reg_model.score(X_test, y_test))

y_pred = gbrt_reg_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# Validation score:  0.8667677659666434
# Train Score:  0.9513365796588781
# Test Score:  0.8905497686035402
# MSE:  15645477765.164137

# %%
from  sklearn.ensemble import GradientBoostingRegressor

gbrt_reg = GradientBoostingRegressor(random_state = 0, learning_rate = 0.1, max_depth = 5, 
                                     max_features = 'log2', n_estimators = 500)
gbrt_reg_model = gbrt_reg.fit(X_train,y_train)

print('Train Score: ',gbrt_reg_model.score(X_train, y_train))
print('Test Score: ',gbrt_reg_model.score(X_test, y_test))

y_pred = gbrt_reg_model.predict(X_test)
print('MSE: ',mean_squared_error(y_test, y_pred))

# %matplotlib inline

plt.subplots(figsize = (40,40))
y_list = gbrt_reg_model.feature_importances_
y_pos = np.arange(len(y_list))
features = X.columns
plt.barh(y_pos, y_list, align='center', alpha=0.4)
plt.yticks(y_pos, features)
# Out:
# Train Score:  0.9513365796588781
# Test Score:  0.8905497686035402
# MSE:  15645477765.164137
# ([<matplotlib.axis.YTick at 0x167fd51da48>,
#   <matplotlib.axis.YTick at 0x167fd2c76c8>,
#   <matplotlib.axis.YTick at 0x167fd4feb48>,
#   <matplotlib.axis.YTick at 0x167d21b9688>,
#   <matplotlib.axis.YTick at 0x167d1f00508>,
#   <matplotlib.axis.YTick at 0x167d1f005c8>,
#   <matplotlib.axis.YTick at 0x167f964d948>,
#   <matplotlib.axis.YTick at 0x167f9637248>,
#   <matplotlib.axis.YTick at 0x167d1f00888>,
#   <matplotlib.axis.YTick at 0x167f9637b48>,
#   <matplotlib.axis.YTick at 0x167f96330c8>,
#   <matplotlib.axis.YTick at 0x167f9633a08>,
#   <matplotlib.axis.YTick at 0x167f98b8408>,
#   <matplotlib.axis.YTick at 0x167f98b8148>,
#   <matplotlib.axis.YTick at 0x167f96a81c8>,
#   <matplotlib.axis.YTick at 0x167d21a3648>,
#   <matplotlib.axis.YTick at 0x167f9676988>,
#   <matplotlib.axis.YTick at 0x167f9676dc8>,
#   <matplotlib.axis.YTick at 0x167f98b8d88>,
#   <matplotlib.axis.YTick at 0x167f9633148>,
#   <matplotlib.axis.YTick at 0x167d21a7748>,
#   <matplotlib.axis.YTick at 0x167f95f6c48>,
#   <matplotlib.axis.YTick at 0x167f96494c8>,
#   <matplotlib.axis.YTick at 0x167f966e408>,
#   <matplotlib.axis.YTick at 0x167f966e3c8>,
#   <matplotlib.axis.YTick at 0x167f962ca08>,
#   <matplotlib.axis.YTick at 0x167f963f688>,
#   <matplotlib.axis.YTick at 0x167f963f7c8>,
#   <matplotlib.axis.YTick at 0x167f966eb88>,
#   <matplotlib.axis.YTick at 0x167d21a7388>,
#   <matplotlib.axis.YTick at 0x167f9672cc8>,
#   <matplotlib.axis.YTick at 0x167f9644048>,
#   <matplotlib.axis.YTick at 0x167f964cf08>,
#   <matplotlib.axis.YTick at 0x167f964c8c8>,
#   <matplotlib.axis.YTick at 0x167f96c9b88>,
#   <matplotlib.axis.YTick at 0x167f96861c8>,
#   <matplotlib.axis.YTick at 0x167f9628088>,
#   <matplotlib.axis.YTick at 0x167fd506e88>,
#   <matplotlib.axis.YTick at 0x167f964ce48>,
#   <matplotlib.axis.YTick at 0x167f9644888>,
#   <matplotlib.axis.YTick at 0x167f9659d48>,
#   <matplotlib.axis.YTick at 0x167f9659cc8>,
#   <matplotlib.axis.YTick at 0x167fd5b4588>,
#   <matplotlib.axis.YTick at 0x167fd4e0448>,
#   <matplotlib.axis.YTick at 0x167fd4e0f48>,
#   <matplotlib.axis.YTick at 0x167f968d248>,
#   <matplotlib.axis.YTick at 0x167fd2d7d88>,
#   <matplotlib.axis.YTick at 0x167fd2d7548>,
#   <matplotlib.axis.YTick at 0x167fd2d7908>,
#   <matplotlib.axis.YTick at 0x167f9672948>,
#   <matplotlib.axis.YTick at 0x168007563c8>,
#   <matplotlib.axis.YTick at 0x167fd552448>,
#   <matplotlib.axis.YTick at 0x167f994a1c8>,
#   <matplotlib.axis.YTick at 0x167f994a6c8>,
#   <matplotlib.axis.YTick at 0x167fd2c2888>,
#   <matplotlib.axis.YTick at 0x167fd2c2708>,
#   <matplotlib.axis.YTick at 0x167f96d4808>,
#   <matplotlib.axis.YTick at 0x167f994a9c8>,
#   <matplotlib.axis.YTick at 0x167fd552388>,
#   <matplotlib.axis.YTick at 0x167f964acc8>,
#   <matplotlib.axis.YTick at 0x167fd2f44c8>,
#   <matplotlib.axis.YTick at 0x167f9651948>,
#   <matplotlib.axis.YTick at 0x167f96512c8>,
#   <matplotlib.axis.YTick at 0x167f98c77c8>,
#   <matplotlib.axis.YTick at 0x167fd499188>,
#   <matplotlib.axis.YTick at 0x167fd499388>,
#   <matplotlib.axis.YTick at 0x167fd52fdc8>,
#   <matplotlib.axis.YTick at 0x1680082e288>,
#   <matplotlib.axis.YTick at 0x167fd52f7c8>,
#   <matplotlib.axis.YTick at 0x167fd53dac8>,
#   <matplotlib.axis.YTick at 0x167fd593ac8>,
#   <matplotlib.axis.YTick at 0x167fd593448>,
#   <matplotlib.axis.YTick at 0x167f96573c8>,
#   <matplotlib.axis.YTick at 0x167f9657f48>,
#   <matplotlib.axis.YTick at 0x167fd5bd1c8>,
#   <matplotlib.axis.YTick at 0x167fd4bfa48>,
#   <matplotlib.axis.YTick at 0x167f9657508>,
#   <matplotlib.axis.YTick at 0x167fd53dd08>,
#   <matplotlib.axis.YTick at 0x167fd4c3d08>,
#   <matplotlib.axis.YTick at 0x167fd4d2588>,
#   <matplotlib.axis.YTick at 0x167fd4d2b08>,
#   <matplotlib.axis.YTick at 0x167fd5432c8>,
#   <matplotlib.axis.YTick at 0x167fd4d5788>],
#  <a list of 83 Text yticklabel objects>)

# %% [markdown]
# sqft_above is the most important feature followed by grade, bathrooms, sqft_living15 and view in descending order of feature importance. Top 5 features in decreasing order of importance are named here.

# %% [markdown]
# ## Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 0.95)
X_train_with_pca = pca.fit_transform(X_train)
X_test_with_pca = pca.transform(X_test)

# %%
X_train_with_pca.shape
# Out:
# (16206, 66)

# %%
X_train.shape
# Out:
# (16206, 83)

# %% [markdown]
# After applying PCA with 95% explained variance, number of features are reduced to 66 from our earlier analysis with 83 features.

# %% [markdown]
# ## Linear Regression with PCA

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lreg = LinearRegression()

lreg.fit(X_train_with_pca, y_train)
print('Train Score: ',lreg.score(X_train_with_pca, y_train))
print('Test Score: ',lreg.score(X_test_with_pca, y_test))

y_pred = lreg.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train Score:  0.7246522481879735
# Test Score:  0.7161870304054059
# MSE:  40569941685.85241

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X_train_rm = X_train_with_pca[:,1].reshape(-1,1)
lreg.fit(X_train_rm, y_train)
y_predict = lreg.predict(X_train_rm)

plt.subplots(figsize = (20,5))
plt.plot(X_train_rm, y_predict, c = 'r')
plt.scatter(X_train_rm,y_train)
plt.xlabel('RM')
# Out:
# Text(0.5, 0, 'RM')

# %% [markdown]
# ## Polynomial Regression with PCA

# %% [markdown]
# Degree : 2

# %%
from  sklearn.preprocessing  import PolynomialFeatures

poly = PolynomialFeatures(degree = 2)
X_train_poly = poly.fit_transform(X_train_with_pca)
X_test_poly = poly.transform(X_test_with_pca)
lreg.fit(X_train_poly, y_train)

train_score = lreg.score(X_train_poly, y_train)
test_score = lreg.score(X_test_poly, y_test)

y_pred = lreg.predict(X_test_poly)
mse = mean_squared_error(y_test, y_pred)
    
print('Train Score: ', train_score)
print('Test Score: ', test_score)
print('MSE: ', mse)
# Out:
# Train Score:  0.8948724839261321
# Test Score:  -3.79962613776998e+19
# MSE:  5.431415310496959e+30

# %% [markdown]
# ## K-Neighbors Regressor with PCA

# %%
from sklearn.neighbors import KNeighborsRegressor

# %matplotlib inline
train_score_array = []
test_score_array = []

for k in range(1,10):
    knn_reg = KNeighborsRegressor(k)
    knn_reg.fit(X_train_with_pca, y_train)
    train_score_array.append(knn_reg.score(X_train_with_pca, y_train))
    test_score_array.append(knn_reg.score(X_test_with_pca, y_test))

x_axis = range(1,10)

plt.subplots(figsize = (20,5))
plt.plot(x_axis, train_score_array, c = 'g', label = 'Train Score')
plt.plot(x_axis, test_score_array, c = 'b', label = 'Test Score')
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

tuned_parameters = dict(n_neighbors = x_axis)

knn_reg = KNeighborsRegressor()
gri1 = GridSearchCV(knn_reg, tuned_parameters, cv = 3, return_train_score = True, iid = False)
gri_model1 = gri1.fit(X_train_with_pca, y_train)

print(gri_model1.best_params_)
print('validation score: ', gri_model1.best_score_)

print('Train Score: ',gri_model1.score(X_train_with_pca, y_train))
print('Test Score: ',gri_model1.score(X_test_with_pca, y_test))

y_pred = gri_model1.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'n_neighbors': 4}
# validation score:  0.7496495568029958
# Train Score:  0.8669970303714798
# Test Score:  0.7863737613950257
# MSE:  30537026039.19648

# %% [markdown]
# ## Ridge Regression with PCA

# %%
from sklearn.linear_model import Ridge
# %matplotlib inline
import matplotlib.pyplot as plt

x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for alpha in x_range: 
    ridge = Ridge(alpha)
    ridge.fit(X_train_with_pca, y_train)
    train_score_list.append(ridge.score(X_train_with_pca, y_train))
    test_score_list.append(ridge.score(X_test_with_pca, y_test))
    

plt.subplots(figsize = (20,5))
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
plt.grid()

# %%
np.random.seed(0)
    
tuned_parameters = [{'alpha':x_range}]

ridge = Ridge(max_iter = 1000, tol = 0.1, random_state = 0)
gri2 = GridSearchCV(ridge, tuned_parameters, cv = 5, return_train_score = True, iid = False)
gri_model2 = gri2.fit(X_train_with_pca, y_train)

print(gri2.best_params_)
print('validation score: ', gri2.best_score_)

print('Train Score: ',gri_model2.score(X_train_with_pca, y_train))
print('Test Score: ',gri_model2.score(X_test_with_pca, y_test))

y_pred = gri_model2.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'alpha': 1}
# validation score:  0.7221226581211901
# Train Score:  0.7246471156552792
# Test Score:  0.7161171782320281
# MSE:  40579926777.811424

# %% [markdown]
# ## Lasso Regression with PCA

# %%
from sklearn.linear_model import Lasso

x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for alpha in x_range: 
    lasso = Lasso(alpha, max_iter = 1000, random_state = 0)
    lasso.fit(X_train_with_pca,y_train)
    train_score_list.append(lasso.score(X_train_with_pca,y_train))
    test_score_list.append(lasso.score(X_test_with_pca, y_test))
    
    
plt.subplots(figsize = (20,5))
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
plt.grid()

# %%
np.random.seed(0)

tuned_parameters = [{'alpha':x_range}]

lasso = Lasso(max_iter = 1000, tol = 0.1, random_state = 0)
gri3 = GridSearchCV(lasso, tuned_parameters, cv = 5, return_train_score = True, iid = False)
gri_model3 = gri3.fit(X_train_with_pca,y_train)

print(gri_model3.best_params_)
print('validation score: ', gri_model3.best_score_)

print('Train Score: ',gri_model3.score(X_train_with_pca, y_train))
print('Test Score: ',gri_model3.score(X_test_with_pca, y_test))

y_pred = gri_model3.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'alpha': 10}
# validation score:  0.7221112813711803
# Train Score:  0.7246486329348276
# Test Score:  0.7161478889811221
# MSE:  40575536797.671844

# %% [markdown]
# ## SGD Regressor with PCA

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(random_state = 0, max_iter = 10000, penalty = 'l2', learning_rate = 'constant', 
                       eta0 = 0.05, shuffle = False)
sgd_reg.fit(X_train_with_pca, y_train)
print('Train Score: ',sgd_reg.score(X_train_with_pca, y_train))
print('Test Score: ',sgd_reg.score(X_test_with_pca, y_test))

print("SGD regression coefficient: " + str(sgd_reg.coef_))
print("SGD regression intercept: " + str(sgd_reg.intercept_))
print("SGD regression iterations: " + str(sgd_reg.n_iter_))

y_pred = sgd_reg.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# Train Score:  0.7099803300192221
# Test Score:  0.698391520149169
# SGD regression coefficient: [ 321318.66651668 1087150.33931537  133259.89067585 -223368.18324174
#   385490.1834798    48858.09088122 -295248.4194576  -159126.72695696
#   124086.19125056  169513.66947729 -106086.72082594  190691.70376087
#    16356.55197332 -123930.64369858 -118261.39170858 -167390.83448448
#   -92441.835321    254828.52835173  401808.9445461   199926.41209644
#   200464.14779331   53564.2695323   286978.03319122 -201245.73637703
#   214778.28709823   35728.52428234   83791.66058749   55809.56202558
#  -182601.01477619 -303273.56744407   50576.33596761  200260.99050931
#  -407198.51947492   61645.15413053   62573.63548751  168667.68852537
#   -10328.32663694   67003.98441451 -107769.00785338  162261.42839026
#   -22040.07728784  -44364.17189541 -113434.85976702  -23369.23265216
#    20919.84962794   29314.51861803   81665.33449444   56059.0505672
#    -3179.3853738    70900.4282609  -160155.81824192  -64397.14000558
#   -41913.91316139  278233.39066784  -97183.13302858  -48378.28519297
#  -149465.24646306  -18340.78540291  145272.79110323 -121210.97217428
#   -55509.16335997  136069.48634126  142224.77489317  -76607.34454711
#   466383.35484269  -48846.30367365]
# SGD regression intercept: [507365.47826486]
# SGD regression iterations: 11
# MSE:  43113739505.93366

# %% [markdown]
# ## SVM Regressor with PCA

# %% [markdown]
# Linear SVR

# %%
from sklearn.svm import LinearSVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for e in [0.01, 0.1, 1, 10]:
        linear = LinearSVR(C = C, epsilon = e)
        linear.fit(X_train_with_pca, y_train) 
        print('Train Score: ',linear.score(X_train_with_pca,y_train),'C: ' ,C,'e: ' ,e)
        print('Test Score: ',linear.score(X_test_with_pca, y_test),'C: ' ,C,'e: ' ,e)
# Out:
# Train Score:  -2.194124311013772 C:  0.01 e:  0.01
# Test Score:  -2.084795024474868 C:  0.01 e:  0.01
# Train Score:  -2.194124311013772 C:  0.01 e:  0.1
# Test Score:  -2.084795024474868 C:  0.01 e:  0.1
# Train Score:  -2.194124311013772 C:  0.01 e:  1
# Test Score:  -2.084795024474868 C:  0.01 e:  1
# Train Score:  -2.194124311013772 C:  0.01 e:  10
# Test Score:  -2.084795024474868 C:  0.01 e:  10
# Train Score:  -2.182242545433953 C:  0.1 e:  0.01
# Test Score:  -2.07366968196057 C:  0.1 e:  0.01
# Train Score:  -2.182242545433953 C:  0.1 e:  0.1
# Test Score:  -2.07366968196057 C:  0.1 e:  0.1
# Train Score:  -2.182242545433953 C:  0.1 e:  1
# Test Score:  -2.07366968196057 C:  0.1 e:  1
# Train Score:  -2.182242545433953 C:  0.1 e:  10
# Test Score:  -2.07366968196057 C:  0.1 e:  10
# Train Score:  -2.0651991270327734 C:  1 e:  0.01
# Test Score:  -1.9640532890386122 C:  1 e:  0.01
# Train Score:  -2.0651991270327734 C:  1 e:  0.1
# Test Score:  -1.9640532890386122 C:  1 e:  0.1
# Train Score:  -2.0651991270327734 C:  1 e:  1
# Test Score:  -1.9640532890386122 C:  1 e:  1
# Train Score:  -2.0651991270327734 C:  1 e:  10
# Test Score:  -1.9640532890386122 C:  1 e:  10
# Train Score:  -1.0929191477753941 C:  10 e:  0.01
# Test Score:  -1.051070820760271 C:  10 e:  0.01
# Train Score:  -1.0929191477753941 C:  10 e:  0.1
# Test Score:  -1.051070820760271 C:  10 e:  0.1
# Train Score:  -1.0929191477753941 C:  10 e:  1
# Test Score:  -1.051070820760271 C:  10 e:  1
# Train Score:  -1.0929191477753941 C:  10 e:  10
# Test Score:  -1.051070820760271 C:  10 e:  10
# Train Score:  0.008252772326172497 C:  100 e:  0.01
# Test Score:  -0.001958785489512449 C:  100 e:  0.01
# Train Score:  0.008170835230779327 C:  100 e:  0.1
# Test Score:  -0.0020391125631460394 C:  100 e:  0.1
# Train Score:  0.007952747415013728 C:  100 e:  1
# Test Score:  -0.0022508181258107385 C:  100 e:  1
# Train Score:  0.007957133774338154 C:  100 e:  10
# Test Score:  -0.002246594903736465 C:  100 e:  10
# Train Score:  0.5489858898620361 C:  1000 e:  0.01
# Test Score:  0.5306376786736067 C:  1000 e:  0.01
# Train Score:  0.5490893152975043 C:  1000 e:  0.1
# Test Score:  0.5307572175364057 C:  1000 e:  0.1
# Train Score:  0.5485960833785481 C:  1000 e:  1
# Test Score:  0.5302840124496284 C:  1000 e:  1
# Train Score:  0.5494194357496427 C:  1000 e:  10
# Test Score:  0.5310825463707312 C:  1000 e:  10
# Train Score:  0.6571035571491826 C:  10000 e:  0.01
# Test Score:  0.6463389881875998 C:  10000 e:  0.01
# Train Score:  0.6570889779035592 C:  10000 e:  0.1
# Test Score:  0.6463618204887727 C:  10000 e:  0.1
# Train Score:  0.6572448193555113 C:  10000 e:  1
# Test Score:  0.646449872506699 C:  10000 e:  1
# Train Score:  0.6568105348834266 C:  10000 e:  10
# Test Score:  0.6459857744153503 C:  10000 e:  10

# %%
from sklearn.svm import LinearSVR
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.01, 0.1, 1, 10, 100, 1000, 10000],
             'epsilon': [0.01, 0.1, 1, 10]}

grid_search_linear = GridSearchCV(LinearSVR(), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_linear = grid_search_linear.fit(X_train_with_pca, y_train) 

print(svr_model_linear.best_params_)
print('Validation score:', svr_model_linear.best_score_)

print('Train Score: ',svr_model_linear.score(X_train_with_pca,y_train))
print('Test Score: ',svr_model_linear.score(X_test_with_pca,y_test))

y_pred = svr_model_linear.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'epsilon': 0.01}
# Validation score: 0.6546263019483165
# Train Score:  0.6573155763659876
# Test Score:  0.6465336181228589
# MSE:  50526621532.3022

# %% [markdown]
# Linear Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for e in [0.01, 0.1, 1, 10]:
        linear = SVR(kernel = 'linear', C = C, epsilon = e)
        linear.fit(X_train_with_pca, y_train) 
        print('Train Score: ',linear.score(X_train_with_pca,y_train),'C: ' ,C,'epsilon: ' ,e)
        print('Test Score: ',linear.score(X_test_with_pca, y_test),'C: ' ,C,'epsilon: ' ,e)
# Out:
# Train Score:  -0.058841829990694094 C:  0.01 epsilon:  0.01
# Test Score:  -0.06454550095913802 C:  0.01 epsilon:  0.01
# Train Score:  -0.05884182999069254 C:  0.01 epsilon:  0.1
# Test Score:  -0.06454550095913647 C:  0.01 epsilon:  0.1
# Train Score:  -0.05884176534582575 C:  0.01 epsilon:  1
# Test Score:  -0.06454543491795017 C:  0.01 epsilon:  1
# Train Score:  -0.05885169202622387 C:  0.01 epsilon:  10
# Test Score:  -0.06455542250303736 C:  0.01 epsilon:  10
# Train Score:  -0.058673269208896484 C:  0.1 epsilon:  0.01
# Test Score:  -0.0643849166299848 C:  0.1 epsilon:  0.01
# Train Score:  -0.058673269373305637 C:  0.1 epsilon:  0.1
# Test Score:  -0.06438491692653958 C:  0.1 epsilon:  0.1
# Train Score:  -0.05867337280312346 C:  0.1 epsilon:  1
# Test Score:  -0.06438502427566539 C:  0.1 epsilon:  1
# Train Score:  -0.05867444229038887 C:  0.1 epsilon:  10
# Test Score:  -0.06438608665119672 C:  0.1 epsilon:  10
# Train Score:  -0.05692176200658294 C:  1 epsilon:  0.01
# Test Score:  -0.0627125655736398 C:  1 epsilon:  0.01
# Train Score:  -0.05692176200658294 C:  1 epsilon:  0.1
# Test Score:  -0.0627125655736398 C:  1 epsilon:  0.1
# Train Score:  -0.05692176200658294 C:  1 epsilon:  1
# Test Score:  -0.0627125655736398 C:  1 epsilon:  1
# Train Score:  -0.05692245133506191 C:  1 epsilon:  10
# Test Score:  -0.06271321252891449 C:  1 epsilon:  10
# Train Score:  -0.03837303580185014 C:  10 epsilon:  0.01
# Test Score:  -0.044929122968409896 C:  10 epsilon:  0.01
# Train Score:  -0.03837315632287197 C:  10 epsilon:  0.1
# Test Score:  -0.04492924405015897 C:  10 epsilon:  0.1
# Train Score:  -0.03837436153984841 C:  10 epsilon:  1
# Test Score:  -0.04493045487388225 C:  10 epsilon:  1
# Train Score:  -0.03838641438516466 C:  10 epsilon:  10
# Test Score:  -0.04494256373442762 C:  10 epsilon:  10
# Train Score:  0.12557820515839258 C:  100 epsilon:  0.01
# Test Score:  0.11289333386383082 C:  100 epsilon:  0.01
# Train Score:  0.125578153662937 C:  100 epsilon:  0.1
# Test Score:  0.11289327892313518 C:  100 epsilon:  0.1
# Train Score:  0.12557763968607605 C:  100 epsilon:  1
# Test Score:  0.11289273046670023 C:  100 epsilon:  1
# Train Score:  0.12557363603352611 C:  100 epsilon:  10
# Test Score:  0.11288858658982069 C:  100 epsilon:  10
# Train Score:  0.5565984864988354 C:  1000 epsilon:  0.01
# Test Score:  0.5380312726449387 C:  1000 epsilon:  0.01
# Train Score:  0.5565985214071658 C:  1000 epsilon:  0.1
# Test Score:  0.5380313108416515 C:  1000 epsilon:  0.1
# Train Score:  0.5565976407659917 C:  1000 epsilon:  1
# Test Score:  0.5380302663443604 C:  1000 epsilon:  1
# Train Score:  0.5565898701225545 C:  1000 epsilon:  10
# Test Score:  0.5380214336741831 C:  1000 epsilon:  10
# Train Score:  0.6576420804706087 C:  10000 epsilon:  0.01
# Test Score:  0.6469045868482032 C:  10000 epsilon:  0.01
# Train Score:  0.6576418722464172 C:  10000 epsilon:  0.1
# Test Score:  0.6469043477006244 C:  10000 epsilon:  0.1
# Train Score:  0.6576397874616716 C:  10000 epsilon:  1
# Test Score:  0.6469019532947331 C:  10000 epsilon:  1
# Train Score:  0.6576385005575995 C:  10000 epsilon:  10
# Test Score:  0.6469002013230358 C:  10000 epsilon:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

param_grid = {'C': [0.1, 1, 100, 1000, 10000],
              'epsilon': [0.01, 0.1, 1, 10]}

grid_search_linear = GridSearchCV(SVR(kernel = 'linear'), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_linear = grid_search_linear.fit(X_train_with_pca, y_train) 

print(svr_model_linear.best_params_)
print('Validation score:', svr_model_linear.best_score_)

print('Train Score: ',svr_model_linear.score(X_train_with_pca,y_train))
print('Test Score: ',svr_model_linear.score(X_test_with_pca,y_test))

y_pred = svr_model_linear.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'epsilon': 10}
# Validation score: 0.6551977127299023
# Train Score:  0.6576385005575995
# Test Score:  0.6469002013230358
# MSE:  50474219913.46345

# %% [markdown]
# RBF Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for g in [0.01, 0.1, 1, 10]:
        rbf = SVR(kernel = 'rbf', C = C, gamma = g)
        rbf.fit(X_train_with_pca, y_train) 
        print('Train Score: ',rbf.score(X_train_with_pca,y_train),'C: ' ,C,'gamma: ' ,g)
        print('Test Score: ',rbf.score(X_test_with_pca, y_test),'C: ' ,C,'gamma: ' ,g)
# Out:
# Train Score:  -0.058860059237787254 C:  0.01 gamma:  0.01
# Test Score:  -0.06456286024248414 C:  0.01 gamma:  0.01
# Train Score:  -0.05885741041057413 C:  0.01 gamma:  0.1
# Test Score:  -0.0645603341908334 C:  0.01 gamma:  0.1
# Train Score:  -0.05885561866504507 C:  0.01 gamma:  1
# Test Score:  -0.06455867636411639 C:  0.01 gamma:  1
# Train Score:  -0.058859573544907784 C:  0.01 gamma:  10
# Test Score:  -0.06456243989171129 C:  0.01 gamma:  10
# Train Score:  -0.05885670747123428 C:  0.1 gamma:  0.01
# Test Score:  -0.0645596637699084 C:  0.1 gamma:  0.01
# Train Score:  -0.05883115856097376 C:  0.1 gamma:  0.1
# Test Score:  -0.06453534975947983 C:  0.1 gamma:  0.1
# Train Score:  -0.058812775264349026 C:  0.1 gamma:  1
# Test Score:  -0.06451830209971221 C:  0.1 gamma:  1
# Train Score:  -0.05885253813345748 C:  0.1 gamma:  10
# Test Score:  -0.06455615193164888 C:  0.1 gamma:  10
# Train Score:  -0.0588242054244168 C:  1 gamma:  0.01
# Test Score:  -0.06452872255484654 C:  1 gamma:  0.01
# Train Score:  -0.05856072572082982 C:  1 gamma:  0.1
# Test Score:  -0.06427752093992978 C:  1 gamma:  0.1
# Train Score:  -0.0583627139507239 C:  1 gamma:  1
# Test Score:  -0.06409272545399691 C:  1 gamma:  1
# Train Score:  -0.05877813428755485 C:  1 gamma:  10
# Test Score:  -0.06448918893033717 C:  1 gamma:  10
# Train Score:  -0.05848954951756635 C:  10 gamma:  0.01
# Test Score:  -0.06420958377355812 C:  10 gamma:  0.01
# Train Score:  -0.05576862590501763 C:  10 gamma:  0.1
# Test Score:  -0.06161049077249836 C:  10 gamma:  0.1
# Train Score:  -0.05360004360318715 C:  10 gamma:  1
# Test Score:  -0.05957107802695072 C:  10 gamma:  1
# Train Score:  -0.05788754705479682 C:  10 gamma:  10
# Test Score:  -0.06367150627852891 C:  10 gamma:  10
# Train Score:  -0.05502415626319057 C:  100 gamma:  0.01
# Test Score:  -0.06089793660192111 C:  100 gamma:  0.01
# Train Score:  -0.026191772125289337 C:  100 gamma:  0.1
# Test Score:  -0.033228494301743794 C:  100 gamma:  0.1
# Train Score:  -0.00380238608891581 C:  100 gamma:  1
# Test Score:  -0.011965439314483241 C:  100 gamma:  1
# Train Score:  -0.04749284046097246 C:  100 gamma:  10
# Test Score:  -0.05397216057347909 C:  100 gamma:  10
# Train Score:  -0.01824789501498225 C:  1000 gamma:  0.01
# Test Score:  -0.025577950030137186 C:  1000 gamma:  0.01
# Train Score:  0.20726899299389534 C:  1000 gamma:  0.1
# Test Score:  0.19174212123717638 C:  1000 gamma:  0.1
# Train Score:  0.28988958939265363 C:  1000 gamma:  1
# Test Score:  0.271410326919874 C:  1000 gamma:  1
# Train Score:  0.04217231668156174 C:  1000 gamma:  10
# Test Score:  0.030083673481772988 C:  1000 gamma:  10
# Train Score:  0.2507911260182767 C:  10000 gamma:  0.01
# Test Score:  0.23403445816838442 C:  10000 gamma:  0.01
# Train Score:  0.593198929761207 C:  10000 gamma:  0.1
# Test Score:  0.5767472357854042 C:  10000 gamma:  0.1
# Train Score:  0.5906077666992865 C:  10000 gamma:  1
# Test Score:  0.5734931489293436 C:  10000 gamma:  1
# Train Score:  0.29750690825712045 C:  10000 gamma:  10
# Test Score:  0.26850428269809323 C:  10000 gamma:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'C': [0.1, 1, 100, 1000, 10000],
              'gamma': [0.01, 0.1, 1, 10]}

grid_search_rbf = GridSearchCV(SVR(kernel = 'rbf'), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_rbf = grid_search_rbf.fit(X_train_with_pca, y_train) 

print(svr_model_rbf.best_params_)
print('Validation score:', svr_model_rbf.best_score_)

print('Train Score: ',svr_model_rbf.score(X_train_with_pca,y_train))
print('Test Score: ',svr_model_rbf.score(X_test_with_pca,y_test))

y_pred = svr_model_rbf.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'gamma': 0.1}
# Validation score: 0.5746923021550324
# Train Score:  0.593198929761207
# Test Score:  0.5767472357854042
# MSE:  60502308922.28067

# %% [markdown]
# Poly Kernel

# %%
from sklearn.svm import SVR

for C in [0.01, 0.1, 1, 10, 100, 1000, 10000]:
    for coef in [0.01, 0.1, 1, 10]:
        poly = SVR(kernel = 'poly', degree = 3, C = C, coef0 = coef)
        poly.fit(X_train_with_pca, y_train)
        print('Train Score: ',poly.score(X_train_with_pca,y_train),'C: ' ,C,'coef0: ' ,coef)
        print('Test Score: ',poly.score(X_test_with_pca, y_test),'C: ' ,C,'coef0: ' ,coef)
# Out:
# Train Score:  -0.058860483903156346 C:  0.01 coef0:  0.01
# Test Score:  -0.06456326796065692 C:  0.01 coef0:  0.01
# Train Score:  -0.05886047368652991 C:  0.01 coef0:  0.1
# Test Score:  -0.06456325815620478 C:  0.01 coef0:  0.1
# Train Score:  -0.05885951995517269 C:  0.01 coef0:  1
# Test Score:  -0.06456234384131343 C:  0.01 coef0:  1
# Train Score:  -0.058775620542531604 C:  0.01 coef0:  10
# Test Score:  -0.0644824379694604 C:  0.01 coef0:  10
# Train Score:  -0.0588604823529999 C:  0.1 coef0:  0.01
# Test Score:  -0.06456326647968114 C:  0.1 coef0:  0.01
# Train Score:  -0.05886038018674067 C:  0.1 coef0:  0.1
# Test Score:  -0.06456316843516197 C:  0.1 coef0:  0.1
# Train Score:  -0.05885185583913377 C:  0.1 coef0:  1
# Test Score:  -0.06455504481845953 C:  0.1 coef0:  1
# Train Score:  -0.05799558004386252 C:  0.1 coef0:  10
# Test Score:  -0.06373849888749161 C:  0.1 coef0:  10
# Train Score:  -0.05886046685143276 C:  1 coef0:  0.01
# Test Score:  -0.06456325166992039 C:  1 coef0:  0.01
# Train Score:  -0.05885946791456531 C:  1 coef0:  0.1
# Test Score:  -0.06456229405259428 C:  1 coef0:  0.1
# Train Score:  -0.05877515221495089 C:  1 coef0:  1
# Test Score:  -0.06448199110170116 C:  1 coef0:  1
# Train Score:  -0.04979540151356909 C:  1 coef0:  10
# Test Score:  -0.05589344501077176 C:  1 coef0:  10
# Train Score:  -0.058860311835779555 C:  10 coef0:  0.01
# Test Score:  -0.0645631035723313 C:  10 coef0:  0.01
# Train Score:  -0.058851352515747024 C:  10 coef0:  0.1
# Test Score:  -0.06455456388312375 C:  10 coef0:  0.1
# Train Score:  -0.0579898544175792 C:  10 coef0:  1
# Test Score:  -0.06373298396735194 C:  10 coef0:  1
# Train Score:  0.032622869365703355 C:  10 coef0:  10
# Test Score:  0.02335354033106707 C:  10 coef0:  10
# Train Score:  -0.058858795107354256 C:  100 coef0:  0.01
# Test Score:  -0.06456165618766319 C:  100 coef0:  0.01
# Train Score:  -0.05877096902714318 C:  100 coef0:  0.1
# Test Score:  -0.06447803786425754 C:  100 coef0:  0.1
# Train Score:  -0.04975293878860598 C:  100 coef0:  1
# Test Score:  -0.05585311330190557 C:  100 coef0:  1
# Train Score:  0.4374736287553742 C:  100 coef0:  10
# Test Score:  0.4172580712518553 C:  100 coef0:  10
# Train Score:  -0.058844583102187986 C:  1000 coef0:  0.01
# Test Score:  -0.06454814436724288 C:  1000 coef0:  0.01
# Train Score:  -0.057934712937839805 C:  1000 coef0:  0.1
# Test Score:  -0.06368007287662003 C:  1000 coef0:  0.1
# Train Score:  0.033054336516983085 C:  1000 coef0:  1
# Test Score:  0.02376647792906927 C:  1000 coef0:  1
# Train Score:  0.6433730512160825 C:  1000 coef0:  10
# Test Score:  0.6303540120072426 C:  1000 coef0:  10
# Train Score:  -0.05870200286648575 C:  10000 coef0:  0.01
# Test Score:  -0.06441255230009535 C:  10000 coef0:  0.01
# Train Score:  -0.04924651634981614 C:  10000 coef0:  0.1
# Test Score:  -0.0553688908747172 C:  10000 coef0:  0.1
# Train Score:  0.43873246605493943 C:  10000 coef0:  1
# Test Score:  0.4185501645191233 C:  10000 coef0:  1
# Train Score:  0.6748662320356342 C:  10000 coef0:  10
# Test Score:  0.6655786620457351 C:  10000 coef0:  10

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'C': [0.1, 1, 10, 100, 1000, 10000],
              'coef0': [0.01, 0.1, 1, 10]}

grid_search_poly = GridSearchCV(SVR(kernel = 'poly'), param_grid, cv=5, return_train_score = True, n_jobs = -1)
svr_model_poly = grid_search_poly.fit(X_train_with_pca, y_train) 

print(svr_model_poly.best_params_)
print('Validation score:', svr_model_poly.best_score_)

print('Train Score: ',svr_model_poly.score(X_train_with_pca,y_train))
print('Test Score: ',svr_model_poly.score(X_test_with_pca,y_test))

y_pred = svr_model_poly.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'C': 10000, 'coef0': 10}
# Validation score: 0.6723458446827121
# Train Score:  0.6748662320356342
# Test Score:  0.6655786620457351
# MSE:  47804207815.76462

# %% [markdown]
# ## Decision Tree Regressor with PCA

# %%
from sklearn.tree import DecisionTreeRegressor

for leaf in [2, 5, 7, 10, 15, 20]:
    dtr = DecisionTreeRegressor(min_samples_leaf = leaf)
    dtr.fit(X_train_with_pca, y_train)
    print('Train Score: ',dtr.score(X_train_with_pca,y_train),'min_samples_leaf: ' ,leaf)
    print('Test Score: ',dtr.score(X_test_with_pca, y_test),'min_samples_leaf: ' ,leaf)
# Out:
# Train Score:  0.9830486543085575 min_samples_leaf:  2
# Test Score:  0.6996219113115052 min_samples_leaf:  2
# Train Score:  0.9245014869021472 min_samples_leaf:  5
# Test Score:  0.7181227261792701 min_samples_leaf:  5
# Train Score:  0.8935947539023895 min_samples_leaf:  7
# Test Score:  0.7091557329704674 min_samples_leaf:  7
# Train Score:  0.8639172480074773 min_samples_leaf:  10
# Test Score:  0.7252878734071037 min_samples_leaf:  10
# Train Score:  0.8269960842339326 min_samples_leaf:  15
# Test Score:  0.7176200625426674 min_samples_leaf:  15
# Train Score:  0.8099614268777355 min_samples_leaf:  20
# Test Score:  0.7166491803853423 min_samples_leaf:  20

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

param_grid = {'min_samples_leaf': range(3,20)}

dtr = GridSearchCV(DecisionTreeRegressor(), param_grid, cv = 5, return_train_score = True, n_jobs = -1)
decision_tree = dtr.fit(X_train_with_pca, y_train)

print(decision_tree.best_params_)
print('Validation score:', decision_tree.best_score_)

print('Train Score: ',decision_tree.score(X_train_with_pca,y_train))
print('Test Score: ',decision_tree.score(X_test_with_pca,y_test))

y_pred = decision_tree.predict(X_test_with_pca)
print('MSE: ',mean_squared_error(y_test, y_pred))
# Out:
# {'min_samples_leaf': 13}
# Validation score: 0.6770589648988836
# Train Score:  0.837159899581537
# Test Score:  0.7254810938104327
# MSE:  39241392074.799904

# %% [markdown]
# ## Deep Learning Model

# %%
X_train_DLM = np.asarray(X_train)
X_test_DLM = np.asarray(X_test)
y_train_DLM = np.asarray(y_train)
y_test_DLM = np.asarray(y_test)

# %%
#import tensorflow as tf
#import keras
#from keras.models import Sequential
#from keras.layers import Dense

#Defining model
#dlm = Sequential()
#dlm.add(Dense(16, input_dim = X_train_DLM.shape[1], kernel_initializer = 'normal', activation = 'sigmoid', name = 'input_layer'))
#dlm.add(Dense(8, activation = 'relu', kernel_initializer='normal', name = 'hidden_layer'))
#dlm.add(Dense(1, kernel_initializer='normal'))

#compiling model
#dlm.compile(loss = 'mse', optimizer = 'sgd', metrics = ['mse', 'mae'])

#fit model
#dlm.fit(X_train_DLM, y_train_DLM, epochs = 20, batch_size = 128)

# %%
#evaluate model
#dlm.evaluate(X_test_DLM, y_test_DLM)

# %%
#from sklearn.metrics import mean_squared_error
#y_pred_DLM = dlm.predict(X_test_DLM)
#print(dlm.evaluate(X_train_DLM,y_train_DLM))
#print(dlm.evaluate(X_test_DLM,y_test_DLM))
#print(mean_squared_error(y_test_DLM, y_pred_DLM))

# %% [markdown]
# # CONCLUSION
#
# ### Ensembling
# | Model | Bagging - SGD Regressor | Pasting - SGD Regressor | Bagging - Decision Tree Regressor | Pasting - Decision Tree Regressor | Adaboost - Linear Regression | Adaboost - Lasso Rgeression | Gradient Boosting |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | max_features | 20 | 20 | 20 | 20 | --- | --- | log2 |
# | max_samples | 0.3 | 0.5 | 0.5 | 0.5 | --- | --- | --- |
# | n_estimators | 20 | 20 | 250 | 250 | 20 | 20 | 500 |
# | learning_rate | --- | --- | --- | --- | 0.05 | 0.05 | 0.1 |
# | loss | --- | --- | --- | --- | exponential | exponential | --- |
# | max_depth | --- | --- | --- | --- | --- | --- | 5 |
# | Training Score | 0.5589871547840561 | 0.5662121617324214 | 0.658800640471781 | 0.6734508635945906 | 0.8028448384554943 | 0.8015160513474398 | 0.9513365796588781 |
# | Validation Score | 0.5677115662754662 | 0.5693555465285673 | 0.6113193325992352 | 0.618597061404007 | 0.7941098699117426 | 0.7943769838727383 | 0.8667677659666434 |
# | Testing score | 0.5509060711366776 | 0.5587716348344909 | 0.6278667258154307 | 0.6354711358183972 | 0.8081187716196271 | 0.8072484926447483 | 0.8905497686035402 |
# | MSE | 64196201221.81469 | 63071849995.010414 | 53194979970.78448 | 52107959631.94532 | 27428662816.647167 | 27553065754.651333 | 15645477765.164137 |
#
#
# ### Project 1 Results
# | Model | Linear Regression | Polynomial Regression | KNN Regressor | Ridge Regression | Lasso Regression | SGD Regressor | Linear SVR | SVM Linear | SVM RBF | SVM Poly | Decision Tree Regressor |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Params | default | degree = 2 | k = 3 | alpha = 0.1 | alpha = 1 | number of iterations = 36 | C = 10000, epsilon = 0.01 | C = 10000, epsilon = 0.01 | C=10000, gamma=0.1 | C = 10, coef0 = 10 | min_samples_leaf = 9 |
# | Training Score | 0.8060 | 0.9145 | 0.8896| 0.8061 | 0.8002 | 0.7943 | 0.7301 | 0.7305 | 0.5975 | 0.7593 | 0.8315 |
# | Validation Score | - | - | 0.7471| 0.8022 | 0.7982 | - | 0.7205 | 0.7212 | 0.5975 | 0.7594 | 0.6801 |
# |Testing score | 0.8094 | -8.7553e+16 | 0.7890 | 0.8093 | 0.8036 | 0.7959 | 0.7225 | 0.7228 | 0.6036 | 0.7552 | 0.7007 |
# | MSE | 27248083255.0241 | 1.2515e+28 | 30167671978.2293 | 27255102161.6693 | 28070156376.8954 | 29169284631.3325 | 39673213678.8975 | 39619998463.59157 | 56668093969.6439 | 34990581867.725494 | 42785533440.2197 |
#
#
# ### Results after PCA
# | Model | Linear Regression | Polynomial Regression | KNN Regressor | Ridge Regression | Lasso Regression | SGD Regressor | Linear SVR | SVM Linear | SVM RBF | SVM Poly | Decision Tree Regressor |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Params | default | degree = 2 | k = 4 | alpha = 1 | alpha = 10 | number of iterations = 11 | C = 10000, epsilon = 10 | C = 10000, epsilon = 10 | C = 10000, gamma = 0.1 | C = 10000, coef0 = 10 | min_samples_leaf = 13 |
# | Training Score | 0.7247 | 0.8957 | 0.8669| 0.7246 | 0.7246 | 0.7099 | 0.6574 | 0.6576 | 0.5932 | 0.6749 | 0.8372 |
# | Validation Score | - | - | 0.7496| 0.7221 | 0.7221 | - | 0.6546 | 0.6552 | 0.5747 | 0.6723 | 0.6769 |
# |Testing score | 0.7162 | -3.998e+18 | 0.7864 | 0.7161 | 0.7161 | 0.6984 | 0.6466 | 0.6469 | 0.5767 | 0.6656 | 0.7255 |
# | MSE | 40569941685.852394 | 5.7144e+29 | 30537026039.19648 | 40579926777.8114 | 40575536797.671814 | 43113739505.933586 | 50518507876.00592 | 50474219913.463615 | 60502308922.281 | 47804207815.762276 | 39241372724.33667 |
#
# Results from Decision Tree regressor are better after PCA.
# Results from KNN are similar with or without PCA.
# For rest of the models, results are better without PCA.
# Linear regression without PCA and Ridge Regression with alpha = 0.1 wihtout PCA are the best models for prediciting the target variable.
